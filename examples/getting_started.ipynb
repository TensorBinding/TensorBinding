# %% [markdown]
# # TensorBinding.jl — Getting Started
#
# End-to-end tour of the core workflows:
#
# 1. **1D chain** — KPM density matrix, LDoS, and A(k,ω) band structure via QFT
# 2. **NNN hopping** — `add_hopping!` to extend an existing Hamiltonian
# 2b. **AAH quasicrystal** — quasiperiodic on-site potential, localisation transition
# 2c. **Custom MPO** — arbitrary hopping matrix compressed via TCI
# 3. **2D square lattice** — density matrix via McWeeny and SP2 purification
# 4. **2D LDoS** — local spectral function at the sample centre
# 5. **Real-time TDVP** — `evolve_with_tdvp`, wavepacket spreading
#
# All physics functions live in `TensorBinding`; the central object is `TBHamiltonian`
# returned by `get_Hamiltonian`.

# %%
import Pkg; Pkg.resolve(); Pkg.instantiate()
# Out:
#     Updating `C:\temp_docs\TensorBinding\TensorBinding.jl\Project.toml`
#   [0d1a4710] + ITensorMPS v0.3.45
#   [9136182c] + ITensors v0.9.25
#   [23ae76d9] + NDTensors v0.4.23
#   [91a5bcdd] + Plots v1.41.6
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.6
#   [87f76fb3] + Quantics v0.4.8
#   [634c7f73] + QuanticsGrids v0.7.2
#   [b11687fd] + QuanticsTCI v0.7.3
#   [9f0aa9f4] + TCIITensorConversion v0.2.1
#   [b261b2ec] + TensorCrossInterpolation v0.9.19
#     Updating `C:\temp_docs\TensorBinding\TensorBinding.jl\Manifest.toml`
#   [7d9f7c33] + Accessors v0.1.44
#   [79e6a3ab] + Adapt v4.5.0
#   [66dad0bd] + AliasTables v1.1.3
#   [dce04be8] + ArgCheck v2.5.0
#   [4fba245c] + ArrayInterface v7.23.0
#   [4c555306] + ArrayLayouts v1.12.2
#   [198e06fe] + BangBang v0.4.9
#   [9718e550] + Baselet v0.1.1
#   [0e736298] + Bessels v0.2.8
#   [d1d4a3ce] + BitFlags v0.1.9
#   [c3b6d118] + BitIntegers v0.3.7
#   [8e7c35d0] + BlockArrays v1.9.3
#   [d360d2e6] + ChainRulesCore v1.26.0
#   [944b1d66] + CodecZlib v0.7.8
#   [35d6a980] + ColorSchemes v3.31.0
#   [3da002f7] + ColorTypes v0.12.1
#   [c3611d14] + ColorVectorSpace v0.11.0
#   [5ae59095] + Colors v0.13.1
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [a33af91c] + CompositionsBase v0.1.2
#   [f0e56b4a] + ConcurrentUtilities v2.5.1
#   [8f4d0f93] + Conda v1.10.3
#   [187b0558] + ConstructionBase v1.6.0
#   [d38c429a] + Contour v0.6.3
#   [9a962f9c] + DataAPI v1.16.0
#   [864edb3b] + DataStructures v0.19.4
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [244e2a9f] + DefineSingletons v0.1.2
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [85a47980] + Dictionaries v0.4.6
#   [ffbed154] + DocStringExtensions v0.9.5
#   [da5c29d0] + EllipsisNotation v1.9.0
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [e2ba6199] + ExprTools v0.1.10
#   [e189563c] + ExternalDocstrings v0.1.1
#   [c87230d0] + FFMPEG v0.4.5
#   [f6e391d2] + FastMPOContractions v0.2.10
#   [1a297f60] + FillArrays v1.16.0
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [41a02a25] + Folds v0.2.10
#   [1fa38f19] + Format v1.3.7
#   [d9f16b24] + Functors v0.5.2
#   [28b8d3ca] + GR v0.73.24
# ⌅ [14197337] + GenericLinearAlgebra v0.3.19
#   [42e2da0e] + Grisu v1.0.2
#   [cd3eb016] + HTTP v1.11.0
#   [f0d1745a] + HalfIntegers v1.6.0
#   [0d1a4710] + ITensorMPS v0.3.45
#   [9136182c] + ITensors v0.9.25
#   [615f187c] + IfElse v0.1.1
#   [313cdc1a] + Indexing v1.1.1
#   [22cec73e] + InitialValues v0.3.1
#   [842dd82b] + InlineStrings v1.4.5
#   [3587e190] + InverseFunctions v0.1.17
#   [92d709cd] + IrrationalConstants v0.2.6
#   [28f27b66] + IsApprox v2.0.0
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [1019f520] + JLFzf v0.1.11
#   [682c06a0] + JSON v1.4.0
#   [0b1a1467] + KrylovKit v0.10.2
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [23fbe1c1] + Latexify v0.16.10
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [e6f89c97] + LoggingExtras v1.2.0
#   [1914dd2f] + MacroTools v0.5.16
#   [739be429] + MbedTLS v1.1.10
#   [442fdcdd] + Measures v0.3.3
#   [128add7d] + MicroCollections v0.2.0
#   [e1d29d7a] + Missings v1.2.0
# ⌅ [bdf0d083] + MultiFloats v2.3.0
#   [23ae76d9] + NDTensors v0.4.23
#   [77ba4419] + NaNMath v1.1.3
#   [4d8831e6] + OpenSSL v1.6.1
#   [bac558e1] + OrderedCollections v1.8.1
#   [65ce6f38] + PackageExtensionCompat v1.0.2
#   [69de0a69] + Parsers v2.8.3
#   [ccf2f8ad] + PlotThemes v3.3.0
#   [995b91a9] + PlotUtils v1.4.4
#   [91a5bcdd] + Plots v1.41.6
# ⌅ [aea7be01] + PrecompileTools v1.2.1
#   [43287f4e] + PtrArrays v1.4.0
#   [438e738f] + PyCall v1.96.4
#   [d330b81b] + PyPlot v2.11.6
#   [1fd47b50] + QuadGK v2.11.2
#   [87f76fb3] + Quantics v0.4.8
#   [634c7f73] + QuanticsGrids v0.7.2
#   [b11687fd] + QuanticsTCI v0.7.3
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [01d81517] + RecipesPipeline v0.6.12
#   [189a3867] + Reexport v1.2.2
#   [42d2dcc6] + Referenceables v0.1.3
#   [05181044] + RelocatableFolders v1.0.1
#   [fdea26ae] + SIMD v3.7.2
#   [431bcebd] + SciMLPublic v1.0.1
#   [6c6a2e73] + Scratch v1.3.0
#   [d3ce8812] + SerializedElementArrays v0.1.0
#   [efcf1570] + Setfield v1.1.2
#   [992d4aef] + Showoff v1.0.3
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [a2af1166] + SortingAlgorithms v1.2.2
# ⌅ [4fe2279e] + SparseIR v1.1.4
#   [03a91e81] + SplitApplyCombine v1.2.3
#   [171d559e] + SplittablesBase v0.1.15
#   [860ef19b] + StableRNGs v1.0.4
#   [aedffcd0] + Static v1.3.1
#   [0d7ed370] + StaticArrayInterface v1.9.0
#   [90137ffa] + StaticArrays v1.9.18
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [10745b16] + Statistics v1.11.1
#   [82ae8749] + StatsAPI v1.8.0
#   [2913bbd2] + StatsBase v0.34.10
#   [5e0ebb24] + Strided v2.3.4
#   [4db3bf67] + StridedViews v0.4.6
#   [ec057cc2] + StructUtils v2.7.1
#   [9f0aa9f4] + TCIITensorConversion v0.2.1
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [62fd8b95] + TensorCore v0.1.1
#   [b261b2ec] + TensorCrossInterpolation v0.9.19
#   [24d252fe] + ThreadedScans v0.1.0
#   [a759f4b9] + TimerOutputs v0.5.29
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [28d57a85] + Transducers v0.4.85
#   [9d95972d] + TupleTools v1.6.0
#   [5c2747f8] + URIs v1.6.1
#   [1cfade01] + UnicodeFun v0.4.1
#   [41fe7b60] + Unzip v0.2.0
#   [409d34a3] + VectorInterface v0.5.0
#   [81def892] + VersionParsing v1.3.0
#   [bd1ec220] + Zeros v0.4.0
#   [6e34b625] + Bzip2_jll v1.0.9+0
#   [83423d85] + Cairo_jll v1.18.5+1
#   [ee1fde0b] + Dbus_jll v1.16.2+0
#   [2702e6a9] + EpollShim_jll v0.0.20230411+1
#   [2e619515] + Expat_jll v2.7.3+0
#   [b22a6f82] + FFMPEG_jll v8.0.1+1
#   [a3f928ae] + Fontconfig_jll v2.17.1+0
#   [d7e528f0] + FreeType2_jll v2.14.3+1
#   [559328eb] + FriBidi_jll v1.0.17+0
#   [0656b61e] + GLFW_jll v3.4.1+0
#   [d2c73de3] + GR_jll v0.73.24+0
# ⌅ [b0724c58] + GettextRuntime_jll v0.22.4+0
#   [61579ee1] + Ghostscript_jll v9.55.1+0
#   [7746bdde] + Glib_jll v2.86.3+0
#   [3b182d85] + Graphite2_jll v1.3.15+0
#   [2e76f6c2] + HarfBuzz_jll v8.5.1+0
#   [aacddb02] + JpegTurbo_jll v3.1.4+0
#   [c1c5ebd0] + LAME_jll v3.100.3+0
#   [88015f11] + LERC_jll v4.0.1+0
#   [1d63c593] + LLVMOpenMP_jll v18.1.8+0
#   [dd4b983a] + LZO_jll v2.10.3+0
# ⌅ [e9f186c6] + Libffi_jll v3.4.7+0
#   [7e76a0d4] + Libglvnd_jll v1.7.1+1
#   [94ce4f54] + Libiconv_jll v1.18.0+0
#   [4b2f31a3] + Libmount_jll v2.41.3+0
#   [89763e89] + Libtiff_jll v4.7.2+0
#   [38a345b3] + Libuuid_jll v2.41.3+0
#   [e7412a2a] + Ogg_jll v1.3.6+0
#   [91d4177d] + Opus_jll v1.6.1+0
#   [36c8627f] + Pango_jll v1.57.0+0
# ⌅ [30392449] + Pixman_jll v0.44.2+0
#   [c0090381] + Qt6Base_jll v6
#    3936.8 ms  ✓ GR
#    3608.8 ms  ✓ ITensorMPS → ITensorMPSChainRulesCoreExt
#    3600.4 ms  ✓ ITensorMPS → ITensorMPSHDF5Ext
#    3694.4 ms  ✓ TensorCrossInterpolation → TCIITensorConversion
#    2915.6 ms  ? TCIITensorConversion
#    3218.7 ms  ✓ FastMPOContractions
#    4485.5 ms  ✓ Quantics
#   54162.7 ms  ✓ Plots
#    5131.9 ms  ? TensorBinding
#   59 dependencies successfully precompiled in 90 seconds. 250 already precompiled.
#   1 dependency precompiled but a different version is currently loaded. Restart julia to access the new version
#   2 dependencies failed but may be precompilable after restarting julia
#   2 dependencies had output during precompilation:
# ┌ TCIITensorConversion
# │  WARNING: Method definition (::Type{ITensorMPS.MPS})(TensorCrossInterpolation.TensorTrain{T, N} where N) where {T} in module TCIITensorConversion at C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\mqCuS\ext\TCIITensorConversion\ttmpsconversion.jl:1 overwritten in module TCIITensorConversion at C:\Users\tiagu\.julia\packages\TCIITensorConversion\lz6XR\src\ttmpsconversion.jl:12.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └
# ┌ TensorBinding
# │  WARNING: Method definition (::Type{ITensorMPS.MPS})(TensorCrossInterpolation.TensorTrain{T, N} where N) where {T} in module TCIITensorConversion at C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\mqCuS\ext\TCIITensorConversion\ttmpsconversion.jl:1 overwritten in module TCIITensorConversion at C:\Users\tiagu\.julia\packages\TCIITensorConversion\lz6XR\src\ttmpsconversion.jl:12.
# │  ERROR: Method overwriting is not permitted during Module precompilation. Use `__precompile__(false)` to opt-out of precompilation.
# └

# %%
using LinearAlgebra
using Plots
using ITensors
using ITensorMPS
include("../src/TensorBinding.jl")
using .TensorBinding
using QuanticsTCI
import TensorCrossInterpolation as TCI
# Out:
# WARNING: replacing module TensorBinding.

# %% [markdown]
# ---
# ## 1. 1D nearest-neighbour chain
#
# $$H = -t \sum_{\langle i,j \rangle} c_i^\dagger c_j$$
#
# `L = 8` qubits encodes `N = 2^8 = 256` physical sites in the quantics binary representation.
# The NN bandwidth is `4|t|`, so `scale = 4.5` comfortably encloses the spectrum.
#
# The `TBHamiltonian` struct wraps the MPO together with `sites`, `scale`, and lazy
# Chebyshev caches shared by all observable methods.

# %%
L  = 8
H1 = TensorBinding.get_Hamiltonian("chain_1d", 1.0; L=L, scale=4.5)
println(H1)
# Out:
# TBHamiltonian | L=8, N=256, scale=4.5, maxlinkdim=3 | geometry: 256 sites, 1D | no Tn cache

# %% [markdown]
# ### 1a. Density matrix via KPM
#
# The Chebyshev list `Tn_list` is built **once** from `H/scale ∈ [-1,1]` and reused
# for every observable (density matrix, LDoS, Green's function). This amortises the
# dominant cost across all subsequent calls to `get_density_from_Tn`,
# `get_ldos_w_from_Tn`, etc.
#
# At half-filling (Fermi level `μ = 0`) we expect `Tr(ρ) ≈ N/2 = 128`.

# %%
Ncheb  = 200
maxdim = 100

Tn_list = TensorBinding.KPM_Tn(H1.mpo / H1.scale, Ncheb, H1.sites; maxdim=maxdim)

# Half-filled density matrix (Fermi level = 0 in rescaled units)
ρ_kpm = TensorBinding.get_density_from_Tn(Tn_list, Ncheb; fermi=0.0, maxdim=maxdim)

println("maxlinkdim(ρ) = ", ITensorMPS.maxlinkdim(ρ_kpm))
println("Tr(ρ)         = ", real(tr(ρ_kpm)), "  (expected ≈ N/2 = ", H1.N ÷ 2, ")")
# Out:
# 5
# 5
# 5
# 6
# 6
# 6
# 6
# 7
# 7
# 7
# 9
# 8
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 10
# 9
# 11
# 11
# 11
# 13
# 12
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 13
# 14
# 13
# 14
# 14
# 14
# 14
# 14
# 14
# 15
# 14
# 15
# 16
# 15
# 16
# 16
# 16
# 16
# 17
# 16
# 16
# 18
# 17
# 19
# 18
# 19
# 18
# 19
# 19
# 19
# 20
# 21
# 20
# 20
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 22
# 22
# 22
# 22
# 22
# 21
# 23
# 21
# 22
# 22
# 21
# 23
# 22
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 22
# 23
# 23
# 23
# 23
# 23
# 23
# 23
# 24
# 24
# 24
# 26
# 26
# 26
# 27
# 27
# 28
# 28
# 28
# 28
# 29
# 28
# 30
# 31
# 31
# 31
# 31
# 31
# 32
# 32
# 32
# 32
# 32
# 33
# 33
# 33
# 34
# 34
# 34
# 34
# 34
# 34
# 35
# 35
# 35
# 37
# 36
# 37
# 38
# 38
# 39
# 39
# 39
# 40
# 40
# 40
# 41
# 41
# 42
# 42
# 42
# 43
# 43
# 43
# 43
# 44
# 43
# 44
# 44
# 44
# 44
# 44
# 44
# 45
# 45
# 45
# 45
# 46
# 45
# 47
# 46
# 47
# 48
# 47
# 49
# 49
# 49
# 49
# maxlinkdim(ρ) = 12
# Tr(ρ)         = 127.99999765433913  (expected ≈ N/2 = 128)

# %% [markdown]
# ### 1b. Local density of states (LDoS)
#
# $$\text{LDoS}(i,\omega) = \langle i \mid \delta(\omega - H) \mid i \rangle$$
#
# Evaluated at the central site by contracting the spectral MPO `δ(ω−H)` with the
# computational-basis state `|i⟩`. Energies are passed in **rescaled** units
# (divide by `H.scale`; multiply back for the plot axis).
#
# The 1D chain has square-root van Hove singularities at the band edges `±2t`.

# %%
ω_phys = range(-3.5, 3.5; length=100)
ω_resc = ω_phys ./ H1.scale

site_idx  = H1.N ÷ 2
psi_site  = TensorBinding.binary_to_MPS(site_idx, H1.L, H1.sites)
ldos_1d   = Float64[]

for ω in ω_resc
    if abs(ω) >= 1.0
        push!(ldos_1d, 0.0)
        continue
    end
    A_mpo = TensorBinding.get_ldos_w_from_Tn(Tn_list, Ncheb, ω; maxdim=maxdim)
    push!(ldos_1d, real(inner(psi_site, apply(A_mpo, psi_site))))
end

plot(ω_phys, ldos_1d;
     xlabel="Energy", ylabel="LDoS",
     title="1D chain — LDoS at site $(site_idx)",
     legend=false, lw=2)

# %% [markdown]
# ### 1c. Band structure A(k,ω) via QFT
#
# In the quantics representation the `L` qubit sites encode real-space position in binary.
# The QFT maps this to momentum space. The correct spectral function is:
#
# $$A(k,\omega) = \langle k \mid F\,\delta(\omega - H)\,F^\dagger \mid k \rangle$$
#
# The k-states are encoded **LSB-first** to match the `QuanticsTCI` QFT convention.
# `get_bands` pre-builds the QFT operators once and loops over ω, reusing `Tn_list`.
# The result is a `(N_k × N_ω)` matrix displayed as a heatmap.

# %%
ω_resc_bands = range(-0.9, 0.9; length=120)
ω_phys_bands = ω_resc_bands .* H1.scale

# Conjugate δ(ω−H) by QFT for each ω → A(k,ω) matrix [N_k × N_ω]
Ak_w = TensorBinding.get_bands(Tn_list, Ncheb, H1.sites, ω_resc_bands;
                                tol=1e-9, maxdim=100)

k_axis = (2π / H1.N) .* (0:H1.N-1) .- π   # BZ: [-π, π)

heatmap(k_axis, collect(ω_phys_bands), Ak_w';
        xlabel="k", ylabel="ω",
        title="1D chain — A(k,ω)",
        color=:inferno, clims=(0, maximum(Ak_w)))

# %% [markdown]
# ---
# ## 2. Adding second-neighbour hopping with `add_hopping!`
#
# `add_hopping!(H, f)` compresses `f(i,j)` via TCI and adds it to the existing MPO,
# automatically invalidating the Chebyshev cache.
#
# $$H = -t_1 \sum_{|i-j|=1} c_i^\dagger c_j - t_2 \sum_{|i-j|=2} c_i^\dagger c_j$$
#
# Exact dispersion: $\varepsilon(k) = -2t_1 \cos k - 2t_2 \cos 2k$,
# overlaid as a dashed curve on the A(k,ω) heatmap.

# %%
t1 = 1.0
t2 = 0.3

H2 = TensorBinding.get_Hamiltonian("chain_1d", t1; L=L, scale=5.5)
TensorBinding.add_hopping!(H2, (i, j) -> abs(i - j) == 2 ? -t2 : 0.0; type=Float64)
println(H2)
# Out:
# MPS COMPUTED!
# Turned into MPO!
# TBHamiltonian | L=8, N=256, scale=5.5, maxlinkdim=5 | geometry: 256 sites, 1D | no Tn cache

# %%
Ncheb_nnn  = 200
Tn_list_h2 = TensorBinding.KPM_Tn(H2.mpo / H2.scale, Ncheb_nnn, H2.sites; maxdim=maxdim)
# Out:
# 9
# 10
# 15
# 15
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 18
# 18
# 18
# 20
# 20
# 22
# 22
# 22
# 23
# 23
# 24
# 24
# 24
# 24
# 26
# 26
# 26
# 28
# 28
# 29
# 30
# 30
# 30
# 30
# 31
# 32
# 32
# 32
# 32
# 33
# 33
# 34
# 35
# 35
# 37
# 36
# 37
# 38
# 38
# 39
# 39
# 39
# 40
# 40
# 40
# 40
# 41
# 42
# 42
# 43
# 43
# 45
# 45
# 45
# 46
# 46
# 47
# 46
# 48
# 48
# 48
# 47
# 48
# 49
# 48
# 49
# 48
# 49
# 48
# 48
# 48
# 49
# 48
# 49
# 48
# 49
# 50
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 50
# 49
# 50
# 49
# 50
# 49
# 51
# 50
# 51
# 50
# 50
# 51
# 50
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 51
# 52
# 51
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 52
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 53
# 200-element Vector{MPO}:
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=1|id=822|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=1|id=453|"Link,l=2"), (dim=1|id=822|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=1|id=76|"Link,l=3"), (dim=1|id=453|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=1|id=159|"Link,l=4"), (dim=1|id=76|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=1|id=513|"Link,l=5"), (dim=1|id=159|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=1|id=329|"Link,l=6"), (dim=1|id=513|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=1|id=123|"Link,l=7"), (dim=1|id=329|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=1|id=123|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=3|id=395|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=3|id=604|"Link,l=2"), (dim=3|id=395|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=3|id=524|"Link,l=3"), (dim=3|id=604|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=3|id=492|"Link,l=4"), (dim=3|id=524|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=5|id=938|"Link,l=5"), (dim=3|id=492|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=5|id=619|"Link,l=6"), (dim=5|id=938|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=3|id=200|"Link,l=7"), (dim=5|id=619|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim
"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=4|id=611|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=4|id=505|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=11|id=456|"Link,l=2"), (dim=4|id=505|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=23|id=916|"Link,l=3"), (dim=11|id=456|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=52|id=357|"Link,l=4"), (dim=23|id=916|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=53|id=285|"Link,l=5"), (dim=52|id=357|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=16|id=987|"Link,l=6"), (dim=53|id=285|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=4|id=501|"Link,l=7"), (dim=16|id=987|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=4|id=501|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=4|id=144|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=11|id=332|"Link,l=2"), (dim=4|id=144|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=23|id=14|"Link,l=3"), (dim=11|id=332|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=52|id=269|"Link,l=4"), (dim=23|id=14|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=53|id=652|"Link,l=5"), (dim=52|id=269|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=16|id=649|"Link,l=6"), (dim=53|id=652|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=4|id=470|"Link,l=7"), (dim=16|id=649|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=4|id=470|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=4|id=510|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=11|id=108|"Link,l=2"), (dim=4|id=510|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=23|id=428|"Link,l=3"), (dim=11|id=108|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=53|id=908|"Link,l=4"), (dim=23|id=428|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=53|id=685|"Link,l=5"), (dim=53|id=908|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=16|id=473|"Link,l=6"), (dim=53|id=685|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=4|id=225|"Link,l=7"), (dim=16|id=473|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=4|id=225|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=968|"Qubit,Site,n=1")', (dim=2|id=968|"Qubit,Site,n=1"), (dim=4|id=298|"Link,l=1"))
# [2] ((dim=2|id=561|"Qubit,Site,n=2")', (dim=2|id=561|"Qubit,Site,n=2"), (dim=11|id=149|"Link,l=2"), (dim=4|id=298|"Link,l=1"))
# [3] ((dim=2|id=191|"Qubit,Site,n=3")', (dim=2|id=191|"Qubit,Site,n=3"), (dim=23|id=268|"Link,l=3"), (dim=11|id=149|"Link,l=2"))
# [4] ((dim=2|id=511|"Qubit,Site,n=4")', (dim=2|id=511|"Qubit,Site,n=4"), (dim=52|id=799|"Link,l=4"), (dim=23|id=268|"Link,l=3"))
# [5] ((dim=2|id=230|"Qubit,Site,n=5")', (dim=2|id=230|"Qubit,Site,n=5"), (dim=53|id=659|"Link,l=5"), (dim=52|id=799|"Link,l=4"))
# [6] ((dim=2|id=767|"Qubit,Site,n=6")', (dim=2|id=767|"Qubit,Site,n=6"), (dim=16|id=383|"Link,l=6"), (dim=53|id=659|"Link,l=5"))
# [7] ((dim=2|id=456|"Qubit,Site,n=7")', (dim=2|id=456|"Qubit,Site,n=7"), (dim=4|id=281|"Link,l=7"), (dim=16|id=383|"Link,l=6"))
# [8] ((dim=2|id=904|"Qubit,Site,n=8")', (dim=2|id=904|"Qubit,Site,n=8"), (dim=4|id=281|"Link,l=7"))

# %%
ω_resc_nnn  = range(-0.9, 0.9; length=120)
ω_phys_nnn  = ω_resc_nnn .* H2.scale

Ak_w_nnn = TensorBinding.get_bands(Tn_list_h2, Ncheb_nnn, H2.sites, ω_resc_nnn;
                                    tol=1e-9, maxdim=100)

k_axis_nnn = (2π / H2.N) .* (0:H2.N-1) .- π

p = heatmap(k_axis_nnn, collect(ω_phys_nnn), Ak_w_nnn';
            xlabel="k", ylabel="ω",
            title="1D chain + NNN — A(k,ω)",
            color=:inferno, clims=(0, maximum(Ak_w_nnn)))

# Overlay exact dispersion
ε_exact = -2t1 .* cos.(k_axis_nnn) .- 2t2 .* cos.(2 .* k_axis_nnn)
plot!(p, k_axis_nnn, ε_exact; lw=1.5, ls=:dash, color=:white, label="exact ε(k)")

# %% [markdown]
# ---
# ## 2b. Aubry-Andre-Harper (AAH) quasicrystal
#
# The AAH model adds a quasiperiodic on-site potential:
#
# $$H = -t \sum_{\langle i,j \rangle} c_i^\dagger c_j + V \sum_i \cos(2\pi b\,i + \phi)\,n_i,
# \qquad b = \frac{1+\sqrt{5}}{2}$$
#
# Exact localisation transition at $V = 2t$:
# - $V < 2t$ — all eigenstates **extended** (metallic), smooth LDoS
# - $V > 2t$ — all eigenstates **localised** (insulating), spiky LDoS
#
# Built via `get_Hamiltonian("aah", (V=..., phi=..., t=...); L=L)`.

# %%
# --- Delocalised phase: V < 2t ---
t_aah = 1.0
H_del = TensorBinding.get_Hamiltonian("aah", (V=1.0, phi=0.0, t=t_aah); L=L, scale=4.5)
println(H_del)

# --- Localised phase: V > 2t ---
H_loc = TensorBinding.get_Hamiltonian("aah", (V=3.0, phi=0.0, t=t_aah); L=L, scale=6.5)
println(H_loc)

# %%
Ncheb_aah = 200

Tn_del = TensorBinding.KPM_Tn(H_del.mpo / H_del.scale, Ncheb_aah, H_del.sites; maxdim=maxdim)
Tn_loc = TensorBinding.KPM_Tn(H_loc.mpo / H_loc.scale, Ncheb_aah, H_loc.sites; maxdim=maxdim)

site_c   = H_del.N ÷ 2
psi_c_del = TensorBinding.binary_to_MPS(site_c, H_del.L, H_del.sites)
psi_c_loc = TensorBinding.binary_to_MPS(site_c, H_loc.L, H_loc.sites)

ω_aah_phys = range(-4.0, 4.0; length=120)

ldos_del = Float64[]
ldos_loc = Float64[]
for ω_p in ω_aah_phys
    ω_d = ω_p / H_del.scale
    ω_l = ω_p / H_loc.scale
    if abs(ω_d) < 1.0
        A = TensorBinding.get_ldos_w_from_Tn(Tn_del, Ncheb_aah, ω_d; maxdim=maxdim)
        push!(ldos_del, real(inner(psi_c_del, apply(A, psi_c_del))))
    else
        push!(ldos_del, 0.0)
    end
    if abs(ω_l) < 1.0
        A = TensorBinding.get_ldos_w_from_Tn(Tn_loc, Ncheb_aah, ω_l; maxdim=maxdim)
        push!(ldos_loc, real(inner(psi_c_loc, apply(A, psi_c_loc))))
    else
        push!(ldos_loc, 0.0)
    end
end

pa = plot(ω_aah_phys, ldos_del; label="V=1 (delocalised)", lw=2,
          xlabel="Energy", ylabel="LDoS", title="AAH — LDoS at central site")
plot!(pa, ω_aah_phys, ldos_loc; label="V=3 (localised)", lw=2, ls=:dash)

# %% [markdown]
# ---
# ## 2c. Custom MPO — spatially modulated hopping
#
# Pass any function `f(i, j)` to `get_Hamiltonian("custom", f; L, scale)` and TCI
# compresses the full `N x N` hopping matrix into an MPO automatically.
#
# Here we use a sinusoidally modulated nearest-neighbour chain:
#
# $$t_{i,i\pm1} = 1 + \delta\cos\!\left(\frac{2\pi i}{\lambda}\right),
# \quad \delta = 0.5,\quad \lambda = N/4$$
#
# The spatial modulation breaks translational symmetry; the LDoS at different
# sites reveals site-dependent spectral weight redistribution.

# %%
δ_mod  = 0.5
λ_mod  = H1.N / 4

# f(i,j): 1-based site indices, NN hopping with a cosine envelope
f_mod(i, j) = abs(i - j) == 1 ?
    -(1.0 + δ_mod * cos(2π * (i + j - 1) / 2 / λ_mod)) : 0.0

H_cust = TensorBinding.get_Hamiltonian("custom", f_mod;
             L=L, scale=5.0, type=Float64)
println(H_cust)

# %%
Ncheb_cust = 200
Tn_cust    = TensorBinding.KPM_Tn(H_cust.mpo / H_cust.scale, Ncheb_cust,
                                   H_cust.sites; maxdim=maxdim)

# DoS = sum of LDoS over all sites — sample a few evenly spaced sites
ω_cust_phys = range(-4.0, 4.0; length=120)
sample_sites = [H_cust.N ÷ 8, H_cust.N ÷ 4, H_cust.N ÷ 2]

ldos_cust = [Float64[] for _ in sample_sites]
psi_cust  = [TensorBinding.binary_to_MPS(s, H_cust.L, H_cust.sites) for s in sample_sites]

for ω_p in ω_cust_phys
    ω_r = ω_p / H_cust.scale
    for (k, psi) in enumerate(psi_cust)
        if abs(ω_r) < 1.0
            A = TensorBinding.get_ldos_w_from_Tn(Tn_cust, Ncheb_cust, ω_r; maxdim=maxdim)
            push!(ldos_cust[k], real(inner(psi, apply(A, psi))))
        else
            push!(ldos_cust[k], 0.0)
        end
    end
end

pc = plot(ω_cust_phys, ldos_cust[1]; label="site $(sample_sites[1])", lw=2,
          xlabel="Energy", ylabel="LDoS",
          title="Custom modulated chain — LDoS at selected sites")
for k in 2:length(sample_sites)
    plot!(pc, ω_cust_phys, ldos_cust[k]; label="site $(sample_sites[k])", lw=2)
end
pc

# %% [markdown]
# ---
# ## 3. 2D square lattice — density matrix via purification
#
# `L = 8` qubits, `Lx = Ly = 4`, `N = 256` sites. 2D NN bandwidth `≈ 8|t|`, `scale = 9`.
#
# Purification iterates a polynomial map on ρ to drive eigenvalues toward exactly 0 or 1,
# approximating $\theta(\mu - H)$ without a Chebyshev expansion.
#
# **Workflow:**
# 1. `purification_initial_guess`: $\rho_0 = (I - H/\mathrm{scale})/2$, spectrum mapped to $[0,1]$
# 2. **McWeeny**: $\rho_{n+1} = 3\rho_n^2 - 2\rho_n^3$, quadratic convergence, 2 MPO products/step
# 3. **SP2**: $\rho_{n+1} = \rho_n^2$ or $2\rho_n - \rho_n^2$ based on $\mathrm{Tr}(\rho^2)$ vs $N_{\mathrm{el}}$, 1 product/step

# %%
Lsq = 8
Lx  = 16
H3  = TensorBinding.get_Hamiltonian("square_2d", 1.0; L=Lsq, Lx=Lx, scale=9.0)
println(H3)
# Out:
# TBHamiltonian | L=8, N=256, scale=9.0, maxlinkdim=4 | geometry: 256 sites, 2D | no Tn cache

# %%
ρ0 = TensorBinding.purification_initial_guess(H3.mpo, H3.scale, H3.sites; maxdim=100, cutoff=1e-8)
println("Tr(ρ₀) = ", real(tr(ρ0)), "  (expected ≈ N/2 = ", H3.N ÷ 2, ")")
# Out:
# Tr(ρ₀) = 127.99999999999997  (expected ≈ N/2 = 128)

# %%
ρ_mc = TensorBinding.mcweeny_purify(ρ0; maxiters=25, maxdim=200, cutoff=1e-8, tol=1e-5, verbose=true)
println("McWeeny → Tr(ρ) = ", real(tr(ρ_mc)),
        "  maxlinkdim = ", ITensorMPS.maxlinkdim(ρ_mc))
# Out:
# McWeeny iter 1: ‖ρ²-ρ‖/‖ρ‖ = 0.4669442192293404, maxlinkdim = 5
# McWeeny iter 2: ‖ρ²-ρ‖/‖ρ‖ = 0.4341195882390856, maxlinkdim = 12
# McWeeny iter 3: ‖ρ²-ρ‖/‖ρ‖ = 0.3825714195548539, maxlinkdim = 17
# McWeeny iter 4: ‖ρ²-ρ‖/‖ρ‖ = 0.32069555027924845, maxlinkdim = 20
# McWeeny iter 5: ‖ρ²-ρ‖/‖ρ‖ = 0.2636482383300577, maxlinkdim = 26
# McWeeny iter 6: ‖ρ²-ρ‖/‖ρ‖ = 0.217145633937761, maxlinkdim = 35
# McWeeny iter 7: ‖ρ²-ρ‖/‖ρ‖ = 0.1796848284846231, maxlinkdim = 45
# McWeeny iter 8: ‖ρ²-ρ‖/‖ρ‖ = 0.14917907805434197, maxlinkdim = 62
# McWeeny iter 9: ‖ρ²-ρ‖/‖ρ‖ = 0.12434152398039536, maxlinkdim = 116
# McWeeny iter 10: ‖ρ²-ρ‖/‖ρ‖ = 0.10581625365395168, maxlinkdim = 157
# McWeeny iter 11: ‖ρ²-ρ‖/‖ρ‖ = 0.09391444086868815, maxlinkdim = 185
# McWeeny iter 12: ‖ρ²-ρ‖/‖ρ‖ = 0.0872153406556808, maxlinkdim = 199
# McWeeny iter 13: ‖ρ²-ρ‖/‖ρ‖ = 0.0841408270539549, maxlinkdim = 200
# McWeeny iter 14: ‖ρ²-ρ‖/‖ρ‖ = 0.08303178747225115, maxlinkdim = 200
# McWeeny iter 15: ‖ρ²-ρ‖/‖ρ‖ = 0.08202638634949845, maxlinkdim = 200
# McWeeny iter 16: ‖ρ²-ρ‖/‖ρ‖ = 0.0808477642851816, maxlinkdim = 200
# McWeeny iter 17: ‖ρ²-ρ‖/‖ρ‖ = 0.07851453723144847, maxlinkdim = 200
# McWeeny iter 18: ‖ρ²-ρ‖/‖ρ‖ = 0.07479246386095795, maxlinkdim = 200
# McWeeny iter 19: ‖ρ²-ρ‖/‖ρ‖ = 0.06889393792873445, maxlinkdim = 200
# McWeeny iter 20: ‖ρ²-ρ‖/‖ρ‖ = 0.06267149650635072, maxlinkdim = 200
# McWeeny iter 21: ‖ρ²-ρ‖/‖ρ‖ = 0.05649764737769573, maxlinkdim = 200
# McWeeny iter 22: ‖ρ²-ρ‖/‖ρ‖ = 0.05216354273785599, maxlinkdim = 200
# McWeeny iter 23: ‖ρ²-ρ‖/‖ρ‖ = 0.049536250651932894, maxlinkdim = 200
# McWeeny iter 24: ‖ρ²-ρ‖/‖ρ‖ = 0.04708256501460147, maxlinkdim = 200
# McWeeny iter 25: ‖ρ²-ρ‖/‖ρ‖ = 0.04536710617538527, maxlinkdim = 200
# McWeeny → Tr(ρ) = 129.68289645112003  maxlinkdim = 200

# %%
Nel   = H3.N ÷ 2
ρ_sp2 = TensorBinding.sp2_purify(ρ0, Nel; maxiters=25, maxdim=200, cutoff=1e-8, tol=1e-5, verbose=true)
println("SP2    → Tr(ρ) = ", real(tr(ρ_sp2)),
        "  maxlinkdim = ", ITensorMPS.maxlinkdim(ρ_sp2))
# Out:
# SP2 iter 1: ‖ρ²-ρ‖/‖ρ‖ = 0.4669442192293404, maxlinkdim = 5
# SP2 iter 2: ‖ρ²-ρ‖/‖ρ‖ = 0.2516846200109349, maxlinkdim = 12
# SP2 iter 3: ‖ρ²-ρ‖/‖ρ‖ = 0.3882264512938582, maxlinkdim = 14
# SP2 iter 4: ‖ρ²-ρ‖/‖ρ‖ = 0.2097970783910696, maxlinkdim = 14
# SP2 iter 5: ‖ρ²-ρ‖/‖ρ‖ = 0.2990739764830302, maxlinkdim = 15
# SP2 iter 6: ‖ρ²-ρ‖/‖ρ‖ = 0.1718194334226542, maxlinkdim = 18
# SP2 iter 7: ‖ρ²-ρ‖/‖ρ‖ = 0.21918122547711394, maxlinkdim = 20
# SP2 iter 8: ‖ρ²-ρ‖/‖ρ‖ = 0.2638026404494445, maxlinkdim = 24
# SP2 iter 9: ‖ρ²-ρ‖/‖ρ‖ = 0.1774800435346332, maxlinkdim = 26
# SP2 iter 10: ‖ρ²-ρ‖/‖ρ‖ = 0.19995895590934948, maxlinkdim = 32
# SP2 iter 11: ‖ρ²-ρ‖/‖ρ‖ = 0.1414362403858294, maxlinkdim = 35
# SP2 iter 12: ‖ρ²-ρ‖/‖ρ‖ = 0.15004290196345837, maxlinkdim = 43
# SP2 iter 13: ‖ρ²-ρ‖/‖ρ‖ = 0.1615061422568114, maxlinkdim = 49
# SP2 iter 14: ‖ρ²-ρ‖/‖ρ‖ = 0.12042988742221916, maxlinkdim = 49
# SP2 iter 15: ‖ρ²-ρ‖/‖ρ‖ = 0.12400860485927886, maxlinkdim = 82
# SP2 iter 16: ‖ρ²-ρ‖/‖ρ‖ = 0.1290219153644256, maxlinkdim = 107
# SP2 iter 17: ‖ρ²-ρ‖/‖ρ‖ = 0.10060180629866106, maxlinkdim = 114
# SP2 iter 18: ‖ρ²-ρ‖/‖ρ‖ = 0.10054532680403033, maxlinkdim = 140
# SP2 iter 19: ‖ρ²-ρ‖/‖ρ‖ = 0.10234994532775753, maxlinkdim = 157
# SP2 iter 20: ‖ρ²-ρ‖/‖ρ‖ = 0.0792586001001295, maxlinkdim = 165
# SP2 iter 21: ‖ρ²-ρ‖/‖ρ‖ = 0.07992401607493489, maxlinkdim = 174
# SP2 iter 22: ‖ρ²-ρ‖/‖ρ‖ = 0.08915710572316185, maxlinkdim = 181
# SP2 iter 23: ‖ρ²-ρ‖/‖ρ‖ = 0.06432575979490188, maxlinkdim = 189
# SP2 iter 24: ‖ρ²-ρ‖/‖ρ‖ = 0.07676150169150879, maxlinkdim = 186
# SP2 iter 25: ‖ρ²-ρ‖/‖ρ‖ = 0.04734370706502868, maxlinkdim = 193
# SP2    → Tr(ρ) = 132.20128281927913  maxlinkdim = 191

# %% [markdown]
# ### Compare to KPM and check idempotency
#
# A perfect projector satisfies $\rho^2 = \rho$, so $\|\rho^2 - \rho\|/\|\rho\| = 0$.
# KPM at finite `Ncheb` leaves Gibbs ringing in the eigenvalue spectrum;
# purification iterates this away to yield a sharper projector at lower bond dimension.

# %%
Tn_sq  = TensorBinding.KPM_Tn(H3.mpo / H3.scale, 80, H3.sites; maxdim=100)
ρ_kpm3 = TensorBinding.get_density_from_Tn(Tn_sq, 80; fermi=0.0, maxdim=100)
println("KPM    → Tr(ρ) = ", real(tr(ρ_kpm3)),
        "  maxlinkdim = ", ITensorMPS.maxlinkdim(ρ_kpm3))

function idempotency_residual(ρ)
    ρ2 = apply(ρ, ρ; cutoff=1e-10)
    return norm(+(ρ2, -1.0 * ρ; cutoff=1e-12)) / norm(ρ)
end

println()
println("Idempotency residual ‖ρ²−ρ‖/‖ρ‖ (0 = perfect projector):")
println("  McWeeny : ", idempotency_residual(ρ_mc))
println("  SP2     : ", idempotency_residual(ρ_sp2))
println("  KPM     : ", idempotency_residual(ρ_kpm3))
# Out:
# 13
# 20
# 22
# 20
# 26
# 27
# 28
# 32
# 32
# 34
# 37
# 37
# 39
# 41
# 41
# 43
# 44
# 45
# 47
# 47
# 48
# 49
# 49
# 50
# 51
# 52
# 52
# 52
# 53
# 54
# 54
# 54
# 55
# 55
# 56
# 56
# 57
# 57
# 58
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# 68
# 69
# 71
# 72
# 73
# 75
# 77
# 79
# 81
# 83
# 84
# 85
# 87
# 89
# 90
# 91
# 92
# 93
# 94
# 94
# 95
# 95
# 96
# 97
# 98
# 98
# 99
# 99
# 99
# 99
# 100
# 100
# KPM    → Tr(ρ) = 127.99993076689861  maxlinkdim = 45
#
# Idempotency residual ‖ρ²−ρ‖/‖ρ‖ (0 = perfect projector):
#   McWeeny : 0.06519321079838732
#   SP2     : 0.0614293202703382
#   KPM     : 0.1355388826419442

# %% [markdown]
# ---
# ## 4. 2D square lattice — LDoS at the sample centre
#
# Same approach as section 1b applied to the 2D Hamiltonian `H3`.
# The 2D square lattice DoS has a logarithmic van Hove singularity at $\omega = 0$
# (saddle point at the M-point of the Brillouin zone), clearly visible in the LDoS
# at a bulk site.

# %%
Ncheb_2d = 80
Tn_sq2   = TensorBinding.KPM_Tn(H3.mpo / H3.scale, Ncheb_2d, H3.sites; maxdim=100)

ω_phys_2d = range(-8.0, 8.0; length=80)
ω_resc_2d = ω_phys_2d ./ H3.scale

Ly = Lx

center     = (Lx ÷ 2) + (Ly ÷ 2) * Lx    # Center site index in row-major order
psi_center = TensorBinding.binary_to_MPS(center, H3.L, H3.sites)
ldos_2d    = Float64[]

for ω in ω_resc_2d
    if abs(ω) >= 1.0
        push!(ldos_2d, 0.0)
        continue
    end
    A_mpo = TensorBinding.get_ldos_w_from_Tn(Tn_sq2, Ncheb_2d, ω; maxdim=200)
    push!(ldos_2d, real(inner(psi_center, apply(A_mpo, psi_center))))
end

plot(ω_phys_2d, ldos_2d;
     xlabel="Energy", ylabel="LDoS",
     title="2D square lattice — LDoS at site $(center)",
     legend=false, lw=2)
# Out:
# 13
# 20
# 22
# 20
# 26
# 27
# 28
# 32
# 32
# 34
# 37
# 37
# 39
# 41
# 41
# 43
# 44
# 45
# 47
# 47
# 48
# 49
# 49
# 50
# 51
# 52
# 52
# 52
# 53
# 54
# 54
# 54
# 55
# 55
# 56
# 56
# 57
# 57
# 58
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# 68
# 69
# 71
# 72
# 73
# 75
# 77
# 79
# 81
# 83
# 84
# 85
# 87
# 89
# 90
# 91
# 92
# 93
# 94
# 94
# 95
# 95
# 96
# 97
# 98
# 98
# 99
# 99
# 99
# 99
# 100
# 100

# %% [markdown]
# ---
# ## 5. Real-time evolution via TDVP
#
# TDVP (Time-Dependent Variational Principle) integrates the Schrodinger equation
# directly on the MPS manifold, keeping the bond dimension bounded at each step.
#
# We use `evolve_with_tdvp` from `TensorBinding.Timeev_tk` on a small 1D chain
# (`L=4`, `N=16`), starting from a superposition of the two central basis states.
# `compute_basis_overlaps` tracks the full probability distribution over the trajectory.

# %% [markdown]
# ### 5a. Hamiltonian and initial state
#
# `L=4` gives `N=16` sites — small enough to track every computational-basis overlap
# explicitly. The initial state is an equal superposition of the two central sites.

# %%
# Small system so the MPO propagator TCI is fast
L_t  = 8
N_t  = 2^L_t

H_t     = TensorBinding.get_Hamiltonian("chain_1d", 1.0; L=L_t, scale=4.5)
sites_t = H_t.sites

# Initial state: equal superposition of the two central basis states
sitemid = N_t ÷ 2
psi0_t  = (
    TensorBinding.binary_to_MPS(sitemid,     L_t, sites_t) +
    TensorBinding.binary_to_MPS(sitemid - 1, L_t, sites_t)
) / sqrt(2)

println(H_t)
println("psi0 norm = ", real(inner(psi0_t, psi0_t)))
# Out:
# TBHamiltonian | L=8, N=256, scale=4.5, maxlinkdim=3 | geometry: 256 sites, 1D | no Tn cache
# psi0 norm = 0.9999999999999998

# %% [markdown]
# ### 5b. TDVP evolution and visualisation
#
# `evolve_with_tdvp` returns the MPS at every time step.
# `compute_basis_overlaps` evaluates `<x|psi(t)>` for all basis states,
# returning the probability distribution as a function of site and step.
# The heatmaps show quantum spreading and interference structure.

# %%
dt_t    = 0.01
nsteps_t = 500

tdvp_states = TensorBinding.evolve_with_tdvp(
    -1im * H_t.mpo, psi0_t, nsteps_t, dt_t;
    normalize_each_step = true,
    maxdim  = 200,
    cutoff  = 1e-10,
    nsite   = 2,
)
# Out:
# 501-element Vector{MPS}:
#  MPS
# [1] ((dim=2|id=35|"Qubit,Site,n=1"), (dim=2|id=889|"Link,l=1"))
# [2] ((dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=970|"Link,l=2"), (dim=2|id=889|"Link,l=1"))
# [3] ((dim=2|id=812|"Qubit,Site,n=3"), (dim=2|id=727|"Link,l=3"), (dim=2|id=970|"Link,l=2"))
# [4] ((dim=2|id=687|"Qubit,Site,n=4"), (dim=2|id=861|"Link,l=4"), (dim=2|id=727|"Link,l=3"))
# [5] ((dim=2|id=392|"Qubit,Site,n=5"), (dim=2|id=866|"Link,l=5"), (dim=2|id=861|"Link,l=4"))
# [6] ((dim=2|id=309|"Qubit,Site,n=6"), (dim=2|id=190|"Link,l=6"), (dim=2|id=866|"Link,l=5"))
# [7] ((dim=2|id=789|"Qubit,Site,n=7"), (dim=2|id=513|"Link,l=7"), (dim=2|id=190|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=513|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=767|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=2|id=207|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=767|"Link,l=1"))
# [3] ((dim=2|id=835|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=2|id=207|"Link,l=2"))
# [4] ((dim=2|id=301|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=2|id=835|"Link,l=3"))
# [5] ((dim=2|id=844|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=2|id=301|"Link,l=4"))
# [6] ((dim=2|id=11|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=2|id=844|"Link,l=5"))
# [7] ((dim=2|id=342|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=2|id=11|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=342|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=687|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=2|id=164|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=687|"Link,l=1"))
# [3] ((dim=2|id=771|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=2|id
"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=931|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=727|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=89|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=4|id=654|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=89|"Link,l=1"))
# [3] ((dim=5|id=222|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=4|id=654|"Link,l=2"))
# [4] ((dim=8|id=635|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=5|id=222|"Link,l=3"))
# [5] ((dim=8|id=824|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=8|id=635|"Link,l=4"))
# [6] ((dim=4|id=216|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=8|id=824|"Link,l=5"))
# [7] ((dim=2|id=289|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=216|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=289|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=909|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=4|id=712|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=909|"Link,l=1"))
# [3] ((dim=5|id=199|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=4|id=712|"Link,l=2"))
# [4] ((dim=8|id=273|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=5|id=199|"Link,l=3"))
# [5] ((dim=8|id=898|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=8|id=273|"Link,l=4"))
# [6] ((dim=4|id=30|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=8|id=898|"Link,l=5"))
# [7] ((dim=2|id=83|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=30|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=83|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=649|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=4|id=757|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=649|"Link,l=1"))
# [3] ((dim=5|id=587|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=4|id=757|"Link,l=2"))
# [4] ((dim=8|id=426|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=5|id=587|"Link,l=3"))
# [5] ((dim=8|id=446|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=8|id=426|"Link,l=4"))
# [6] ((dim=4|id=43|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=8|id=446|"Link,l=5"))
# [7] ((dim=2|id=479|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=43|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=479|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=191|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=4|id=732|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=191|"Link,l=1"))
# [3] ((dim=5|id=850|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=4|id=732|"Link,l=2"))
# [4] ((dim=8|id=93|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=5|id=850|"Link,l=3"))
# [5] ((dim=8|id=25|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=8|id=93|"Link,l=4"))
# [6] ((dim=4|id=416|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=8|id=25|"Link,l=5"))
# [7] ((dim=2|id=957|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=416|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=957|"Link,l=7"))
#
#  MPS
# [1] ((dim=2|id=131|"Link,l=1"), (dim=2|id=35|"Qubit,Site,n=1"))
# [2] ((dim=4|id=739|"Link,l=2"), (dim=2|id=241|"Qubit,Site,n=2"), (dim=2|id=131|"Link,l=1"))
# [3] ((dim=5|id=233|"Link,l=3"), (dim=2|id=812|"Qubit,Site,n=3"), (dim=4|id=739|"Link,l=2"))
# [4] ((dim=8|id=876|"Link,l=4"), (dim=2|id=687|"Qubit,Site,n=4"), (dim=5|id=233|"Link,l=3"))
# [5] ((dim=8|id=661|"Link,l=5"), (dim=2|id=392|"Qubit,Site,n=5"), (dim=8|id=876|"Link,l=4"))
# [6] ((dim=4|id=779|"Link,l=6"), (dim=2|id=309|"Qubit,Site,n=6"), (dim=8|id=661|"Link,l=5"))
# [7] ((dim=2|id=497|"Link,l=7"), (dim=2|id=789|"Qubit,Site,n=7"), (dim=4|id=779|"Link,l=6"))
# [8] ((dim=2|id=878|"Qubit,Site,n=8"), (dim=2|id=497|"Link,l=7"))

# %%
tdvp_data  = TensorBinding.compute_basis_overlaps(tdvp_states, L_t, sites_t)
steps_axis = 0:nsteps_t
basis_axis = 0:(N_t - 1)

p1 = heatmap(basis_axis, steps_axis, tdvp_data.abs_overlaps;
    xlabel="x", ylabel="step", title="TDVP: |⟨x|ψ(t)⟩|", color=:inferno)
p2 = heatmap(basis_axis, steps_axis, tdvp_data.probabilities;
    xlabel="x", ylabel="step", title="TDVP: |⟨x|ψ(t)⟩|²", color=:inferno)
p3 = plot(steps_axis, tdvp_data.abs_overlaps[:, sitemid];
    xlabel="step", ylabel="|⟨x₀|ψ⟩|", title="Overlap with initial state", legend=false)
p4 = plot(steps_axis, tdvp_data.norms;
    xlabel="step", ylabel="⟨ψ|ψ⟩", title="Norm during evolution", legend=false)

display(plot(p1, p2; layout=(1,2), size=(900,350)))
display(plot(p3, p4; layout=(1,2), size=(900,300)))

# %%
using ITensors
using ITensorMPS

N = 4

# Site indices
sites = siteinds("S=1/2", N)

# Manually define link indices
links = [Index(3, "l_$i") for i in 1:N-1]

# Build MPO tensors manually
W = Vector{ITensor}(undef, N)

for i in 1:N
    s = sites[i]
    sp = prime(s)

    if i == 1
        # left boundary (only right link)
        W[i] = ITensor(s, sp, links[i])
    elseif i == N
        # right boundary (only left link)
        W[i] = ITensor(links[i-1], s, sp)
    else
        # bulk tensor (both links)
        W[i] = ITensor(links[i-1], s, sp, links[i])
    end
end

# Example: fill with identity operator
for i in 1:N
    s = sites[i]
    sp = prime(s)

    if i == 1
        W[i][s=>1, sp=>1, links[i]=>1] = 1.0
    elseif i == N
        W[i][links[i-1]=>1, s=>1, sp=>1] = 1.0
    else
        W[i][links[i-1]=>1, s=>1, sp=>1, links[i]=>1] = 1.0
    end
end

# Construct MPO
H = ITensorMPS.MPO(W, sites)
# Out:
# ITensor constructor with input arguments of types `(Vector{ITensor}, Index{Int64}, Index{Int64}, Index{Int64}, Index{Int64})` not defined.
#
# Stacktrace:
#  [1] error(s::String)
#    @ Base .\error.jl:35
#  [2] ITensor(::NDTensors.AllowAlias, ::Vector{ITensor}, ::Vararg{Any}; kwargs::@Kwargs{})
#    @ ITensors C:\Users\tiagu\.julia\packages\ITensors\GrLgo\src\itensor.jl:144
#  [3] itensor(::Vector{ITensor}, ::Vararg{Any}; kwargs::@Kwargs{})
#    @ ITensors C:\Users\tiagu\.julia\packages\ITensors\GrLgo\src\itensor.jl:142
#  [4] MPO(A::Vector{ITensor}, sites::Vector{Index{Int64}}; kwargs::@Kwargs{})
#    @ ITensorMPS C:\Users\tiagu\.julia\packages\ITensorMPS\fZDBz\src\abstractmps.jl:2016
#  [5] MPO(A::Vector{ITensor}, sites::Vector{Index{Int64}})
#    @ ITensorMPS C:\Users\tiagu\.julia\packages\ITensorMPS\fZDBz\src\abstractmps.jl:2015
#  [6] top-level scope
#    @ In[9]:46

# %% [markdown]
# ---
# ## 6. Driven square lattice — Peierls field and RK4 density-matrix evolution
#
# The x-direction hopping picks up a time-dependent Peierls phase from an AC electric field:
#
# $$H(t) = H_y + t_x \sum_{\langle i,j\rangle_x} \left(e^{i A_x(t)}\, c^\dagger_{i+1} c_i + \text{h.c.}\right)$$
#
# with vector potential $A_x(t) = \frac{E_x}{\omega}\sin(\omega t)\,\Theta(t)$ turned on at $t = 0$.
#
# The single-particle density matrix $\rho(t)$ is propagated by $\dot\rho = -i[H(t),\rho]$ using RK4.
#
# **Efficiency trick**: decompose the Peierls phase as
# $$H_x(t) = \cos(A_x)\,H_x^{\rm real} + \sin(A_x)\,H_x^{\rm imag}$$
# where $H_x^{\rm real}$, $H_x^{\rm imag}$ are fixed MPOs built once — each time step is then just two scalings and two MPO additions.

# %%
# --- Parameters ---
Ldrv   = 8        # 2^10 = 1024 sites total
Lx_drv = 2^4       # 32x32 square lattice
N_drv  = 2^Ldrv

t_x    = 1.0      # x-hopping amplitude
t_y    = 1.0      # y-hopping (isotropic)
omega  = 1.0      # drive frequency
E_x    = 0.5      # drive amplitude  (A_x peak = E_x/omega)

dt_drv     = 0.1
nsteps_drv = round(Int, 4 * 2pi / (omega * dt_drv))  # 4 full drive cycles

# --- Equilibrium Hamiltonian H0 (no field) ---
H0_drv    = TensorBinding.get_Hamiltonian("square_2d", t_x;
                L=Ldrv, Lx=Lx_drv, scale=9.0)
sites_drv = H0_drv.sites

# --- Pre-build the two static Peierls MPO components ---
#
#   H_x(t) = cos(Ax) * H_x_real + sin(Ax) * H_x_imag
#
#   H_x_real = intrachain_hopping(...; t=t_x)     = t_x*(hop_fwd + hop_bwd)
#   H_x_imag = intrachain_hopping(...; t=im*t_x)  = i*t_x*(hop_fwd - hop_bwd)
#
# With Peierls:  e^{iAx}*hop_fwd + e^{-iAx}*hop_bwd
#              = cos(Ax)*(hop_fwd+hop_bwd) + i*sin(Ax)*(hop_fwd-hop_bwd)
#              = cos(Ax)*H_x_real + sin(Ax)*H_x_imag   (check: i*(hop_fwd-hop_bwd) = H_x_imag/t_x)
H_x_real = TensorBinding.intrachain_hopping(Lx_drv, N_drv, sites_drv; t =      t_x)
H_x_imag = TensorBinding.intrachain_hopping(Lx_drv, N_drv, sites_drv; t = 1im * t_x)
H_y_drv  = TensorBinding.interchain_hopping_square(Lx_drv, N_drv, sites_drv; t = t_y)

# --- Time-dependent Hamiltonian closure (only MPO additions at each call) ---
A_x(t)    = t > 0 ? (E_x / omega) * sin(omega * t) : 0.0

function Hoft_drv(t)
    Ax    = A_x(t)
    H_x_t = +(cos(Ax) * H_x_real, sin(Ax) * H_x_imag; cutoff=1e-10)
    return +(H_x_t, H_y_drv; cutoff=1e-10)
end

# --- Initial density matrix: zero-temperature half-filling ground state of H0 ---
rho_guess = TensorBinding.purification_initial_guess(
                H0_drv.mpo, H0_drv.scale, sites_drv;
                maxdim=100, cutoff=1e-8)
rho0_drv  = TensorBinding.mcweeny_purify(rho_guess;
                maxiters=50, maxdim=200, cutoff=1e-8, tol=1e-5, verbose=true)
println("Tr(rho0) = ", real(tr(rho0_drv)), "  (target: ", N_drv / 2, ")")

# --- RK4 time evolution ---
states_drv = TensorBinding.evolve_rk4_dm_timedep(
    Hoft_drv, rho0_drv, nsteps_drv, Float64(dt_drv);
    maxdim=300, cutoff=1e-10, truncate_intermediates=true, verbose=true)
# Out:
# McWeeny iter 1: ‖ρ²-ρ‖/‖ρ‖ = 0.466876689094888, maxlinkdim = 4
# McWeeny iter 2: ‖ρ²-ρ‖/‖ρ‖ = 0.43399112266890894, maxlinkdim = 9
# McWeeny iter 3: ‖ρ²-ρ‖/‖ρ‖ = 0.382364964267818, maxlinkdim = 10
# McWeeny iter 4: ‖ρ²-ρ‖/‖ρ‖ = 0.32043910027012446, maxlinkdim = 12
# McWeeny iter 5: ‖ρ²-ρ‖/‖ρ‖ = 0.26340237839656183, maxlinkdim = 16
# McWeeny iter 6: ‖ρ²-ρ‖/‖ρ‖ = 0.21696857251262375, maxlinkdim = 22
# McWeeny iter 7: ‖ρ²-ρ‖/‖ρ‖ = 0.17958830400393744, maxlinkdim = 28
# McWeeny iter 8: ‖ρ²-ρ‖/‖ρ‖ = 0.14911718171175434, maxlinkdim = 28
# McWeeny iter 9: ‖ρ²-ρ‖/‖ρ‖ = 0.12428221764100027, maxlinkdim = 30
# McWeeny iter 10: ‖ρ²-ρ‖/‖ρ‖ = 0.10644806370226259, maxlinkdim = 31
# McWeeny iter 11: ‖ρ²-ρ‖/‖ρ‖ = 0.0967378635362263, maxlinkdim = 34
# McWeeny iter 12: ‖ρ²-ρ‖/‖ρ‖ = 0.09192814470381425, maxlinkdim = 35
# McWeeny iter 13: ‖ρ²-ρ‖/‖ρ‖ = 0.09004931469147444, maxlinkdim = 38
# McWeeny iter 14: ‖ρ²-ρ‖/‖ρ‖ = 0.0897230019051855, maxlinkdim = 38
# McWeeny iter 15: ‖ρ²-ρ‖/‖ρ‖ = 0.08956637957934074, maxlinkdim = 39
# McWeeny iter 16: ‖ρ²-ρ‖/‖ρ‖ = 0.08922001492319037, maxlinkdim = 40
# McWeeny iter 17: ‖ρ²-ρ‖/‖ρ‖ = 0.08843363605072432, maxlinkdim = 40
# McWeeny iter 18: ‖ρ²-ρ‖/‖ρ‖ = 0.08672704744658935, maxlinkdim = 41
# McWeeny iter 19: ‖ρ²-ρ‖/‖ρ‖ = 0.08329199021435438, maxlinkdim = 41
# McWeeny iter 20: ‖ρ²-ρ‖/‖ρ‖ = 0.07731164782877716, maxlinkdim = 42
# McWeeny iter 21: ‖ρ²-ρ‖/‖ρ‖ = 0.0691216420474652, maxlinkdim = 42
# McWeeny iter 22: ‖ρ²-ρ‖/‖ρ‖ = 0.06033010040738753, maxlinkdim = 43
# McWeeny iter 23: ‖ρ²-ρ‖/‖ρ‖ = 0.05169935271287479, maxlinkdim = 43
# McWeeny iter 24: ‖ρ²-ρ‖/‖ρ‖ = 0.043874191987728677, maxlinkdim = 43
# McWeeny iter 25: ‖ρ²-ρ‖/‖ρ‖ = 0.036759006161207156, maxlinkdim = 43
# McWeeny iter 26: ‖ρ²-ρ‖/‖ρ‖ = 0.03057309294042565, maxlinkdim = 42
# McWeeny iter 27: ‖ρ²-ρ‖/‖ρ‖ = 0.025380782896827644, maxlinkdim = 42
# McWeeny iter 28: ‖ρ²-ρ‖/‖ρ‖ = 0.022778627636491865, maxlinkdim = 43
# McWeeny iter 29: ‖ρ²-ρ‖/‖ρ‖ = 0.02244140851436826, maxlinkdim = 45
# McWeeny iter 30: ‖ρ²-ρ‖/‖ρ‖ = 0.02243960319696792, maxlinkdim = 46
# McWeeny iter 31: ‖ρ²-ρ‖/‖ρ‖ = 0.022436981448619813, maxlinkdim = 46
# McWeeny iter 32: ‖ρ²-ρ‖/‖ρ‖ = 0.022435912380564176, maxlinkdim = 47
# McWeeny iter 33: ‖ρ²-ρ‖/‖ρ‖ = 0.022431268863359343, maxlinkdim = 49
# McWeeny iter 34: ‖ρ²-ρ‖/‖ρ‖ = 0.022422111083074302, maxlinkdim = 49
# McWeeny iter 35: ‖ρ²-ρ‖/‖ρ‖ = 0.022396738059592396, maxlinkdim = 49
# McWeeny iter 36: ‖ρ²-ρ‖/‖ρ‖ = 0.02234394259990723, maxlinkdim = 49
# McWeeny iter 37: ‖ρ²-ρ‖/‖ρ‖ = 0.02222861945937137, maxlinkdim = 48
# McWeeny iter 38: ‖ρ²-ρ‖/‖ρ‖ = 0.02195808224850642, maxlinkdim = 49
# McWeeny iter 39: ‖ρ²-ρ‖/‖ρ‖ = 0.0213749834535577, maxlinkdim = 49
# McWeeny iter 40: ‖ρ²-ρ‖/‖ρ‖ = 0.02010730247484013, maxlinkdim = 49
# McWeeny iter 41: ‖ρ²-ρ‖/‖ρ‖ = 0.017544065465476356, maxlinkdim = 48
# McWeeny iter 42: ‖ρ²-ρ‖/‖ρ‖ = 0.01296649529738033, maxlinkdim = 47
# McWeeny iter 43: ‖ρ²-ρ‖/‖ρ‖ = 0.006712264592619727, maxlinkdim = 48
# McWeeny iter 44: ‖ρ²-ρ‖/‖ρ‖ = 0.0017663120151024606, maxlinkdim = 47
# McWeeny iter 45: ‖ρ²-ρ‖/‖ρ‖ = 0.0007442251127746413, maxlinkdim = 47
# McWeeny iter 46: ‖ρ²-ρ‖/‖ρ‖ = 0.0008082915285003036, maxlinkdim = 49
# McWeeny iter 47: ‖ρ²-ρ‖/‖ρ‖ = 0.0006789786717163228, maxlinkdim = 50
# McWeeny iter 48: ‖ρ²-ρ‖/‖ρ‖ = 0.0007880285062298705, maxlinkdim = 50
# McWeeny iter 49: ‖ρ²-ρ‖/‖ρ‖ = 0.0006549335925123164, maxlinkdim = 51
# McWeeny iter 50: ‖ρ²-ρ‖/‖ρ‖ = 0.0008548577263146996, maxlinkdim = 53
# Tr(rho0) = 124.00008284051455  (target: 128.0)
# RK4 step 1 / 251,  t = 0.0,  maxlinkdim = 56
# RK4 step 2 / 251,  t = 0.1,  maxlinkdim = 57
# RK4 step 3 / 251,  t = 0.2,  maxlinkdim = 58
# RK4 step 4 / 251,  t = 0.30000000000000004,  maxlinkdim = 59
# RK4 step 5 / 251,  t = 0.4,  maxlinkdim = 60
# RK4 step 6 / 251,  t = 0.5,  maxlinkdim = 61
# RK4 step 7 / 251,  t = 0.6000000000000001,  maxlinkdim = 61
# RK4 step 8 / 251,  t = 0.7000000000000001,  maxlinkdim = 61
# RK4 step 9 / 251,  t = 0.8,  maxlinkdim = 61
# RK4 step 10 / 251,  t = 0.9,  maxlinkdim = 61
# RK4 step 11 / 251,  t = 1.0,  maxlinkdim = 61
# RK4 step 12 / 251,  t = 1.1,  maxlinkdim = 61
# RK4 step 13 / 251,  t = 1.2000000000000002,  maxlinkdim = 61
# RK4 step 14 / 251,  t = 1.3,  maxlinkdim = 61
# RK4 step 15 / 251,  t = 1.4000000000000001,  maxlinkdim = 61
# RK4 step 16 / 251,  t = 1.5,  maxlinkdim = 61
# RK4 step 17 / 251,  t = 1.6,  maxlinkdim = 61
# RK4 step 18 / 251,  t = 1.7000000000000002,  maxlinkdim = 61
# RK4 step 19 / 251,  t = 1.8,  maxlinkdim = 61
# RK4 step 20 / 251,  t = 1.9000000000000001,  maxlinkdim = 62
# RK4 step 21 / 251,  t = 2.0,  maxlinkdim = 62
# RK4 step 22 / 251,  t = 2.1,  maxlinkdim = 62
# RK4 step 23 / 251,  t = 2.2,  maxlinkdim = 62
# RK4 step 24 / 251,  t = 2.3000000000000003,  maxlinkdim = 62
# RK4 step 25 / 251,  t = 2.4000000000000004,  maxlinkdim = 62
# RK4 step 26 / 251,  t = 2.5,  maxlinkdim = 62
# RK4 step 27 / 251,  t = 2.6,  maxlinkdim = 62
# RK4 step 28 / 251,  t = 2.7,  maxlinkdim = 62
# RK4 step 29 / 251,  t = 2.8000000000000003,  maxlinkdim = 62
# RK4 step 30 / 251,  t = 2.9000000000000004,  maxlinkdim = 62
# RK4 step 31 / 251,  t = 3.0,  maxlinkdim = 62
# RK4 step 32 / 251,  t = 3.1,  maxlinkdim = 62
# RK4 step 33 / 251,  t = 3.2,  maxlinkdim = 63
# RK4 step 34 / 251,  t = 3.3000000000000003,  maxlinkdim = 63
# RK4 step 35 / 251,  t = 3.4000000000000004,  maxlinkdim = 63
# RK4 step 36 / 251,  t = 3.5,  maxlinkdim = 63
# RK4 step 37 / 251,  t = 3.6,  maxlinkdim = 63
# RK4 step 38 / 251,  t = 3.7,  maxlinkdim = 63
# RK4 step 39 / 251,  t = 3.8000000000000003,  maxlinkdim = 63
# RK4 step 40 / 251,  t = 3.9000000000000004,  maxlinkdim = 63
# RK4 step 41 / 251,  t = 4.0,  maxlinkdim = 63
# RK4 step 42 / 251,  t = 4.1000000000000005,  maxlinkdim = 63
# RK4 step 43 / 251,  t = 4.2,  maxlinkdim = 63
# RK4 step 44 / 251,  t = 4.3,  maxlinkdim = 63
# RK4 step 45 / 251,  t = 4.4,  maxlinkdim = 64
# RK4 step 46 / 251,  t = 4.5,  maxlinkdim = 64
# RK4 step 47 / 251,  t = 4.6000000000000005,  maxlinkdim = 64
# RK4 step 48 / 251,  t = 4.7,  maxlinkdim = 64
# RK4 step 49 / 251,  t = 4.800000000000001,  maxlinkdim = 64
# RK4 step 50 / 251,  t = 4.9,  maxlinkdim = 64
# RK4 step 51 / 251,  t = 5.0,  maxlinkdim = 64
# RK4 step 52 / 251,  t = 5.1000000000000005,  maxlinkdim = 64
# RK4 step 53 / 251,  t = 5.2,  maxlinkdim = 64
# RK4 step 54 / 251,  t = 5.300000000000001,  maxlinkdim = 64
# RK4 step 55 / 251,  t = 5.4,  maxlinkdim = 64
# RK4 step 56 / 251,  t = 5.5,  maxlinkdim = 64
# RK4 step 57 / 251,  t = 5.6000000000000005,  maxlinkdim = 64
# RK4 step 58 / 251,  t = 5.7,  maxlinkdim = 64
# RK4 step 59 / 251,  t = 5.800000000000001,  maxlinkdim = 64
# RK4 step 60 / 251,  t = 5.9,  maxlinkdim = 64
# RK4 step 61 / 251,  t = 6.0,  maxlinkdim = 64
# RK4 step 62 / 251,  t = 6.1000000000000005,  maxlinkdim = 64
# RK4 step 63 / 251,  t = 6.2,  maxlinkdim = 64
# RK4 step 64 / 251,  t = 6.300000000000001,  maxlinkdim = 64
# RK4 step 65 / 251,  t = 6.4,  maxlinkdim = 64
# RK4 step 66 / 251,  t = 6.5,  maxlinkdim = 64
# RK4 step 67 / 251,  t = 6.6000000000000005,  maxlinkdim = 64
# RK4 step 68 / 251,  t = 6.7,  maxlinkdim = 64
# RK4 step 69 / 251,  t = 6.800000000000001,  maxlinkdim = 64
# RK4 step 70 / 251,  t = 6.9,  maxlinkdim = 64
# RK4 step 71 / 251,  t = 7.0,  maxlinkdim = 64
# RK4 step 72 / 251,  t = 7.1000000000000005,  maxlinkdim = 64
# RK4 step 73 / 251,  t = 7.2,  maxlinkdim = 64
# RK4 step 74 / 251,  t = 7.300000000000001,  maxlinkdim = 64
# RK4 step 75 / 251,  t = 7.4,  maxlinkdim = 64
# RK4 step 76 / 251,  t = 7.5,  maxlinkdim = 64
# RK4 step 77 / 251,  t = 7.6000000000000005,  maxlinkdim = 64
# RK4 step 78 / 251,  t = 7.7,  maxlinkdim = 64
# RK4 step 79 / 251,  t = 7.800000000000001,  maxlinkdim = 64
# RK4 step 80 / 251,  t = 7.9,  maxlinkdim = 64
# RK4 step 81 / 251,  t = 8.0,  maxlinkdim = 64
# RK4 step 82 / 251,  t = 8.1,  maxlinkdim = 64
# RK4 step 83 / 251,  t = 8.200000000000001,  maxlinkdim = 64
# RK4 step 84 / 251,  t = 8.3,  maxlinkdim = 64
# RK4 step 85 / 251,  t = 8.4,  maxlinkdim = 64
# RK4 step 86 / 251,  t = 8.5,  maxlinkdim = 64
# RK4 step 87 / 251,  t = 8.6,  maxlinkdim = 64
# RK4 step 88 / 251,  t = 8.700000000000001,  maxlinkdim = 64
# RK4 step 89 / 251,  t = 8.8,  maxlinkdim = 64
# RK4 step 90 / 251,  t = 8.9,  maxlinkdim = 64
# RK4 step 91 / 251,  t = 9.0,  maxlinkdim = 64
# RK4 step 92 / 251,  t = 9.1,  maxlinkdim = 64
# RK4 step 93 / 251,  t = 9.200000000000001,  maxlinkdim = 64
# RK4 step 94 / 251,  t = 9.3,  maxlinkdim = 64
# RK4 step 95 / 251,  t = 9.4,  maxlinkdim = 64
# RK4 step 96 / 251,  t = 9.5,  maxlinkdim = 64
# RK4 step 97 / 251,  t = 9.600000000000001,  maxlinkdim = 64
# RK4 step 98 / 251,  t = 9.700000000000001,  maxlinkdim = 64
# RK4 step 99 / 251,  t = 9.8,  maxlinkdim = 64
# RK4 step 100 / 251,  t = 9.9,  maxlinkdim = 64
# RK4 step 101 / 251,  t = 10.0,  maxlinkdim = 64
# RK4 step 102 / 251,  t = 10.100000000000001,  maxlinkdim = 64
# RK4 step 103 / 251,  t = 10.200000000000001,  maxlinkdim = 64
# RK4 step 104 / 251,  t = 10.3,  maxlinkdim = 64
# RK4 step 105 / 251,  t = 10.4,  maxlinkdim = 64
# RK4 step 106 / 251,  t = 10.5,  maxlinkdim = 64
# RK4 step 107 / 251,  t = 10.600000000000001,  maxlinkdim = 64
# RK4 step 108 / 251,  t = 10.700000000000001,  maxlinkdim = 64
# RK4 step 109 / 251,  t = 10.8,  maxlinkdim = 64
# RK4 step 110 / 251,  t = 10.9,  maxlinkdim = 64
# RK4 step 111 / 251,  t = 11.0,  maxlinkdim = 64
# RK4 step 112 / 251,  t = 11.100000000000001,  maxlinkdim = 64
# RK4 step 113 / 251,  t = 11.200000000000001,  maxlinkdim = 64
# RK4 step 114 / 251,  t = 11.3,  maxlinkdim = 64
# RK4 step 115 / 251,  t = 11.4,  maxlinkdim = 64
# RK4 step 116 / 251,  t = 11.5,  maxlinkdim = 64
# RK4 step 117 / 251,  t = 11.600000000000001,  maxlinkdim = 64
# RK4 step 118 / 251,  t = 11.700000000000001,  maxlinkdim = 64
# RK4 step 119 / 251,  t = 11.8,  maxlinkdim = 64
# RK4 step 120 / 251,  t = 11.9,  maxlinkdim = 64
# RK4 step 121 / 251,  t = 12.0,  maxlinkdim = 64
# RK4 step 122 / 251,  t = 12.100000000000001,  maxlinkdim = 64
# RK4 step 123 / 251,  t = 12.200000000000001,  maxlinkdim = 64
# RK4 step 124 / 251,  t = 12.3,  maxlinkdim = 64
# RK4 step 125 / 251,  t = 12.4,  maxlinkdim = 64
# RK4 step 126 / 251,  t = 12.5,  maxlinkdim = 64
# RK4 step 127 / 251,  t = 12.600000000000001,  maxlinkdim = 64
# RK4 step 128 / 251,  t = 12.700000000000001,  maxlinkdim = 64
# RK4 step 129 / 251,  t = 12.8,  maxlinkdim = 64
# RK4 step 130 / 251,  t = 12.9,  maxlinkdim = 64
# RK4 step 131 / 251,  t = 13.0,  maxlinkdim = 64
# RK4 step 132 / 251,  t = 13.100000000000001,  maxlinkdim = 64
# RK4 step 133 / 251,  t = 13.200000000000001,  maxlinkdim = 64
# RK4 step 134 / 251,  t = 13.3,  maxlinkdim = 64
# RK4 step 135 / 251,  t = 13.4,  maxlinkdim = 64
# RK4 step 136 / 251,  t = 13.5,  maxlinkdim = 64
# RK4 step 137 / 251,  t = 13.600000000000001,  maxlinkdim = 64
# RK4 step 138 / 251,  t = 13.700000000000001,  maxlinkdim = 64
# RK4 step 139 / 251,  t = 13.8,  maxlinkdim = 64
# RK4 step 140 / 251,  t = 13.9,  maxlinkdim = 64
# RK4 step 141 / 251,  t = 14.0,  maxlinkdim = 64
# RK4 step 142 / 251,  t = 14.100000000000001,  maxlinkdim = 64
# RK4 step 143 / 251,  t = 14.200000000000001,  maxlinkdim = 64
# RK4 step 144 / 251,  t = 14.3,  maxlinkdim = 64
# RK4 step 145 / 251,  t = 14.4,  maxlinkdim = 64
# RK4 step 146 / 251,  t = 14.5,  maxlinkdim = 64
# RK4 step 147 / 251,  t = 14.600000000000001,  maxlinkdim = 64
# RK4 step 148 / 251,  t = 14.700000000000001,  maxlinkdim = 64
# RK4 step 149 / 251,  t = 14.8,  maxlinkdim = 64
# RK4 step 150 / 251,  t = 14.9,  maxlinkdim = 64
# RK4 step 151 / 251,  t = 15.0,  maxlinkdim = 64
# RK4 step 152 / 251,  t = 15.100000000000001,  maxlinkdim = 64
# RK4 step 153 / 251,  t = 15.200000000000001,  maxlinkdim = 64
# RK4 step 154 / 251,  t = 15.3,  maxlinkdim = 64
# RK4 step 155 / 251,  t = 15.4,  maxlinkdim = 64
# RK4 step 156 / 251,  t = 15.5,  maxlinkdim = 64
# RK4 step 157 / 251,  t = 15.600000000000001,  maxlinkdim = 64
# RK4 step 158 / 251,  t = 15.700000000000001,  maxlinkdim = 64
# RK4 step 159 / 251,  t = 15.8,  maxlinkdim = 64
# RK4 step 160 / 251,  t = 15.9,  maxlinkdim = 64
# RK4 step 161 / 251,  t = 16.0,  maxlinkdim = 64
# RK4 step 162 / 251,  t = 16.1,  maxlinkdim = 64
# RK4 step 163 / 251,  t = 16.2,  maxlinkdim = 64
# RK4 step 164 / 251,  t = 16.3,  maxlinkdim = 64
# RK4 step 165 / 251,  t = 16.400000000000002,  maxlinkdim = 64
# RK4 step 166 / 251,  t = 16.5,  maxlinkdim = 64
# RK4 step 167 / 251,  t = 16.6,  maxlinkdim = 64
# RK4 step 168 / 251,  t = 16.7,  maxlinkdim = 64
# RK4 step 169 / 251,  t = 16.8,  maxlinkdim = 64
# RK4 step 170 / 251,  t = 16.900000000000002,  maxlinkdim = 64
# RK4 step 171 / 251,  t = 17.0,  maxlinkdim = 64
# RK4 step 172 / 251,  t = 17.1,  maxlinkdim = 64
# RK4 step 173 / 251,  t = 17.2,  maxlinkdim = 64
# RK4 step 174 / 251,  t = 17.3,  maxlinkdim = 64
# RK4 step 175 / 251,  t = 17.400000000000002,  maxlinkdim = 64
# RK4 step 176 / 251,  t = 17.5,  maxlinkdim = 64
# RK4 step 177 / 251,  t = 17.6,  maxlinkdim = 64
# RK4 step 178 / 251,  t = 17.7,  maxlinkdim = 64
# RK4 step 179 / 251,  t = 17.8,  maxlinkdim = 64
# RK4 step 180 / 251,  t = 17.900000000000002,  maxlinkdim = 64
# RK4 step 181 / 251,  t = 18.0,  maxlinkdim = 64
# RK4 step 182 / 251,  t = 18.1,  maxlinkdim = 64
# RK4 step 183 / 251,  t = 18.2,  maxlinkdim = 64
# RK4 step 184 / 251,  t = 18.3,  maxlinkdim = 64
# RK4 step 185 / 251,  t = 18.400000000000002,  maxlinkdim = 64
# RK4 step 186 / 251,  t = 18.5,  maxlinkdim = 64
# RK4 step 187 / 251,  t = 18.6,  maxlinkdim = 64
# RK4 step 188 / 251,  t = 18.7,  maxlinkdim = 64
# RK4 step 189 / 251,  t = 18.8,  maxlinkdim = 64
# RK4 step 190 / 251,  t = 18.900000000000002,  maxlinkdim = 64
# RK4 step 191 / 251,  t = 19.0,  maxlinkdim = 64
# RK4 step 192 / 251,  t = 19.1,  maxlinkdim = 64
# RK4 step 193 / 251,  t = 19.200000000000003,  maxlinkdim = 64
# RK4 step 194 / 251,  t = 19.3,  maxlinkdim = 64
# RK4 step 195 / 251,  t = 19.400000000000002,  maxlinkdim = 64
# RK4 step 196 / 251,  t = 19.5,  maxlinkdim = 64
# RK4 step 197 / 251,  t = 19.6,  maxlinkdim = 64
# RK4 step 198 / 251,  t = 19.700000000000003,  maxlinkdim = 64
# RK4 step 199 / 251,  t = 19.8,  maxlinkdim = 64
# RK4 step 200 / 251,  t = 19.900000000000002,  maxlinkdim = 64
# RK4 step 201 / 251,  t = 20.0,  maxlinkdim = 64
# RK4 step 202 / 251,  t = 20.1,  maxlinkdim = 64
# RK4 step 203 / 251,  t = 20.200000000000003,  maxlinkdim = 64
# RK4 step 204 / 251,  t = 20.3,  maxlinkdim = 64
# RK4 step 205 / 251,  t = 20.400000000000002,  maxlinkdim = 64
# RK4 step 206 / 251,  t = 20.5,  maxlinkdim = 64
# RK4 step 207 / 251,  t = 20.6,  maxlinkdim = 64
# RK4 step 208 / 251,  t = 20.700000000000003,  maxlinkdim = 64
# RK4 step 209 / 251,  t = 20.8,  maxlinkdim = 64
# RK4 step 210 / 251,  t = 20.900000000000002,  maxlinkdim = 64
# RK4 step 211 / 251,  t = 21.0,  maxlinkdim = 64
# RK4 step 212 / 251,  t = 21.1,  maxlinkdim = 64
# RK4 step 213 / 251,  t = 21.200000000000003,  maxlinkdim = 64
# RK4 step 214 / 251,  t = 21.3,  maxlinkdim = 64
# RK4 step 215 / 251,  t = 21.400000000000002,  maxlinkdim = 64
# RK4 step 216 / 251,  t = 21.5,  maxlinkdim = 64
# RK4 step 217 / 251,  t = 21.6,  maxlinkdim = 64
# RK4 step 218 / 251,  t = 21.700000000000003,  maxlinkdim = 64
# RK4 step 219 / 251,  t = 21.8,  maxlinkdim = 64
# RK4 step 220 / 251,  t = 21.900000000000002,  maxlinkdim = 64
# RK4 step 221 / 251,  t = 22.0,  maxlinkdim = 64
# RK4 step 222 / 251,  t = 22.1,  maxlinkdim = 64
# RK4 step 223 / 251,  t = 22.200000000000003,  maxlinkdim = 64
# RK4 step 224 / 251,  t = 22.3,  maxlinkdim = 64
# RK4 step 225 / 251,  t = 22.400000000000002,  maxlinkdim = 64
# RK4 step 226 / 251,  t = 22.5,  maxlinkdim = 64
# RK4 step 227 / 251,  t = 22.6,  maxlinkdim = 64
# RK4 step 228 / 251,  t = 22.700000000000003,  maxlinkdim = 64
# RK4 step 229 / 251,  t = 22.8,  maxlinkdim = 64
# RK4 step 230 / 251,  t = 22.900000000000002,  maxlinkdim = 64
# RK4 step 231 / 251,  t = 23.0,  maxlinkdim = 64
# RK4 step 232 / 251,  t = 23.1,  maxlinkdim = 64
# RK4 step 233 / 251,  t = 23.200000000000003,  maxlinkdim = 64
# RK4 step 234 / 251,  t = 23.3,  maxlinkdim = 64
# RK4 step 235 / 251,  t = 23.400000000000002,  maxlinkdim = 64
# RK4 step 236 / 251,  t = 23.5,  maxlinkdim = 64
# RK4 step 237 / 251,  t = 23.6,  maxlinkdim = 64
# RK4 step 238 / 251,  t = 23.700000000000003,  maxlinkdim = 64
# RK4 step 239 / 251,  t = 23.8,  maxlinkdim = 64
# RK4 step 240 / 251,  t = 23.900000000000002,  maxlinkdim = 64
# RK4 step 241 / 251,  t = 24.0,  maxlinkdim = 64
# RK4 step 242 / 251,  t = 24.1,  maxlinkdim = 64
# RK4 step 243 / 251,  t = 24.200000000000003,  maxlinkdim = 64
# RK4 step 244 / 251,  t = 24.3,  maxlinkdim = 64
# RK4 step 245 / 251,  t = 24.400000000000002,  maxlinkdim = 64
# RK4 step 246 / 251,  t = 24.5,  maxlinkdim = 64
# RK4 step 247 / 251,  t = 24.6,  maxlinkdim = 64
# RK4 step 248 / 251,  t = 24.700000000000003,  maxlinkdim = 64
# RK4 step 249 / 251,  t = 24.8,  maxlinkdim = 64
# RK4 step 250 / 251,  t = 24.900000000000002,  maxlinkdim = 64
# RK4 step 251 / 251,  t = 25.0,  maxlinkdim = 64
# 252-element Vector{MPO}:
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=308|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=12|id=849|"Link,l=2"), (dim=4|id=308|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=39|id=686|"Link,l=3"), (dim=12|id=849|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=381|"Link,l=4"), (dim=39|id=686|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=50|id=602|"Link,l=5"), (dim=56|id=381|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=780|"Link,l=6"), (dim=50|id=602|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=291|"Link,l=7"), (dim=16|id=780|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=291|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=758|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=203|"Link,l=2"), (dim=4|id=758|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=55|id=709|"Link,l=3"), (dim=16|id=203|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=240|"Link,l=4"), (dim=55|id=709|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=57|id=164|"Link,l=5"), (dim=56|id=240|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=719|"Link,l=6"), (dim=57|id=164|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=115|"Link,l=7"), (dim=16|id=719|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=115|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=557|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=497|"Link,l=2"), (dim=4|id=557|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=57|id=552|"Link,l=3"), (dim=16|id=497|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=764|"Link,l=4"), (dim=57|id=552|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=58|id=461|"Link,l=5"), (dim=56|id=764|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=301|"Link,l=6"), (dim=58|id=461|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=479|"Link,l=7"), (dim=16|id=301|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=479|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=846|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=933|"Link,l=2"), (dim=4|id=846|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=57|id=169|"Link,l=3"), (dim=16|id=933|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=656|"Link,l=4"), (dim=57|id=169|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=59|id=627|"Link,l=5"), (dim=56|id=656|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=631|"Link,l=6"), (dim=59|id=627|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=72|"Link,l=7"), (dim=16|id=631|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=72|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=910|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=560|"Link,l=2"), (dim=4|id=910|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=57|id=698|"Link,l=3"), (dim=16|id=560|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=417|"Link,l=4"), (dim=57|id=698|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=60|id=554|"Link,l=5"), (dim=56|id=417|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=970|"Link,l=6"), (dim=60|id=554|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=595|"Link,l=7"), (dim=16|id=970|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=595|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=321|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=437|"Link,l=2"), (dim=4|id=321|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=57|id=45|"Link,l=3"), (dim=16|id=437|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=670|"Link,l=4"), (dim=57|id=45|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=61|id=750|"Link,l=5"), (dim=56|id=670|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=67|"Link,l=6"), (dim=61|id=750|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=849|"Link,l=7"), (dim=16|id=67|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=849|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=867|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=399|"Link,l=2"), (dim=4|id=867|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=57|id=755|"Link,l=3"), (dim=16|id=399|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=677|"Link,l=4"), (dim=57|id=755|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=61|id=97|"Link,l=5"), (dim=56|id=677|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=845|"Link,l=6"), (dim=61|id=97|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=376|"Link,l=7"), (dim=16|id=845|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=376|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=69|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=768|"Link,l=2"), (dim=4|id=69|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim=58|id=205|"Link,l=3"), (dim=16|id=768|"Link,l=2"))
# [4] ((dim=2|id=167|"Qubit,Site,n=4")', (dim=2|id=167|"Qubit,Site,n=4"), (dim=56|id=893|"Link,l=4"), (dim=58|id=205|"Link,l=3"))
# [5] ((dim=2|id=439|"Qubit,Site,n=5")', (dim=2|id=439|"Qubit,Site,n=5"), (dim=61|id=976|"Link,l=5"), (dim=56|id=893|"Link,l=4"))
# [6] ((dim=2|id=998|"Qubit,Site,n=6")', (dim=2|id=998|"Qubit,Site,n=6"), (dim=16|id=784|"Link,l=6"), (dim=61|id=976|"Link,l=5"))
# [7] ((dim=2|id=522|"Qubit,Site,n=7")', (dim=2|id=522|"Qubit,Site,n=7"), (dim=4|id=302|"Link,l=7"), (dim=16|id=784|"Link,l=6"))
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=302|"Link,l=7"))
#
#  MPO
# [1] ((dim=2|id=943|"Qubit,Site,n=1")', (dim=2|id=943|"Qubit,Site,n=1"), (dim=4|id=756|"Link,l=1"))
# [2] ((dim=2|id=507|"Qubit,Site,n=2")', (dim=2|id=507|"Qubit,Site,n=2"), (dim=16|id=978|"Link,l=2"), (dim=4|id=756|"Link,l=1"))
# [3] ((dim=2|id=508|"Qubit,Site,n=3")', (dim=2|id=508|"Qubit,Site,n=3"), (dim
# [8] ((dim=2|id=835|"Qubit,Site,n=8")', (dim=2|id=835|"Qubit,Site,n=8"), (dim=4|id=414|"Link,l=7"))

# %%
taxis = (0:nsteps_drv) .* dt_drv

# Particle number Tr(rho): conserved under unitary evolution — good sanity check
N_t = [real(tr(rho)) for rho in states_drv]

# Energy Tr(H(t) rho(t)): changes as the field pumps energy in
E_t = TensorBinding.timedep_observable_trajectory(
          Hoft_drv, states_drv, Float64(dt_drv))

# Bond dimension of rho(t): tracks entanglement growth
bonddim_t = [ITensorMPS.maxlinkdim(rho) for rho in states_drv]

p1 = plot(taxis, N_t;
    xlabel="t", ylabel="Tr(rho)", title="Particle number (conserved)",
    lw=2, legend=false)

p2 = plot(taxis, E_t;
    xlabel="t", ylabel="<H(t)>", title="Energy",
    lw=2, legend=false)

p3 = plot(taxis, bonddim_t;
    xlabel="t", ylabel="max bond dim", title="Bond dimension of rho(t)",
    lw=2, legend=false, seriestype=:steppost)

display(plot(p1, p2, p3; layout=(1,3), size=(1100,320),
    plot_title="Driven 8x8 lattice:  E_x=$E_x, omega=$omega"))

# %%
# --- Bond-resolved x-current density ---
#
# Builds one MPO per x-direction bond and computes
#   ⟨J_{j→j+1}(t)⟩ = −2 Im(t_eff(t) · ρ^SP_{j,j+1}(t))
# with t_eff(t) = t_x · exp(i·A_x(t)).  Each bond MPO is rank-1
# (single nonzero matrix entry) so QTCI converges in one step.
#
bonds_drv, J_density_drv = TensorBinding.bond_current_density_trajectory(
    A_x, t_x, Lx_drv, N_drv, sites_drv, states_drv, Float64(dt_drv)
)

# Left-site index of each bond (0-indexed physical site j in j→j+1)
bond_idx = [j for (j, _) in bonds_drv]

# Heatmap: bond index on y-axis, time on x-axis
p_bonds = heatmap(taxis, bond_idx, J_density_drv';
    xlabel         = "t",
    ylabel         = "bond  j → j+1  (site j)",
    title          = "x-current  ⟨J_{j,j+1}(t)⟩",
    color          = :RdBu,
    colorbar_title = "current",
)

# Total current = sum over all x-bonds (cross-check against current_operator_trajectory)
J_total_drv = vec(sum(J_density_drv; dims=2))

p_total = plot(taxis, J_total_drv;
    xlabel  = "t",
    ylabel  = "⟨J_total(t)⟩",
    title   = "Total x-current (sum over bonds)",
    lw      = 2,
    legend  = false,
)

display(plot(p_bonds, p_total; layout=(2, 1), size=(900, 650),
    plot_title="Bond current — driven $(Lx_drv)×$(Lx_drv) lattice:  E_x=$E_x, ω=$omega"))
# Out:
# maxsamplevalue is zero!
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] TensorCrossInterpolation.TensorCI2{ComplexF64}(func::TensorCrossInterpolation.CachedFunction{ComplexF64, UInt128}, localdims::Vector{Int64}, initialpivots::Vector{Vector{Int64}})
#     @ TensorCrossInterpolation C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\RnYi9\src\tensorci2.jl:51
#   [3] crossinterpolate2(::Type{ComplexF64}, f::Function, localdims::Vector{Int64}, initialpivots::Vector{Vector{Int64}}; kwargs::@Kwargs{nsearchglobalpivot::Int64, tolerance::Float64, strictlynested::Bool})
#     @ TensorCrossInterpolation C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\RnYi9\src\tensorci2.jl:908
#   [4] quanticscrossinterpolate(::Type{ComplexF64}, f::Main.TensorBinding.var"#284#285"{Int64, Int64}, grid::QuanticsGrids.DiscretizedGrid{2}, initialpivots::Nothing; nrandominitpivot::Int64, kwargs::@Kwargs{tolerance::Float64})
#     @ QuanticsTCI C:\Users\tiagu\.julia\packages\QuanticsTCI\83MQR\src\tciinterface.jl:114
#   [5] hopping2MPO(f::Function, N::Int64, sites::Vector{Index{Int64}}; tol::Float64, initial_positions::Vector{Tuple{Int64, Int64}}, type::Type)
#     @ Main.TensorBinding c:\temp_docs\TensorBinding\TensorBinding.jl\src\Hamiltonian.jl:114
#   [6] hopping2MPO
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Hamiltonian.jl:100 [inlined]
#   [7] #single_bond_current_mpo#283
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:567 [inlined]
#   [8] single_bond_current_mpo
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:564 [inlined]
#   [9] #289
#     @ .\none:0 [inlined]
#  [10] iterate
#     @ .\generator.jl:48 [inlined]
#  [11] collect(itr::Base.Generator{Vector{Tuple{Int64, Int64}}, Main.TensorBinding.var"#289#292"{Float64, Int64, Vector{Index{Int64}}}})
#     @ Base .\array.jl:791
#  [12] #xbond_current_mpos#286
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:587 [inlined]
#  [13] xbond_current_mpos
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:585 [inlined]
#  [14] bond_current_density_trajectory(Aoft::typeof(A_x), t_x::Float64, Lx::Int64, N::Int64, sites::Vector{Index{Int64}}, states::Vector{MPO}, dt::Float64; cutoff::Float64)
#     @ Main.TensorBinding c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:619
#  [15] bond_current_density_trajectory(Aoft::Function, t_x::Float64, Lx::Int64, N::Int64, sites::Vector{Index{Int64}}, states::Vector{MPO}, dt::Float64)
#     @ Main.TensorBinding c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:615
#  [16] top-level scope
#     @ In[15]:8

# %%
# --- Local bond current  J_j(t) = i·t_x(t)·(ρ_{j,j+1} − ρ_{j+1,j}) ---
#
# xbond_current_mpos builds one MPO per x-direction bond such that
#   inner(mpo_j, ρ) = Tr(c†_{j+1} c_j · ρ)  =  ρ_{j+1,j}
#
# By hermiticity  ρ_{j,j+1} = conj(ρ_{j+1,j}), so
#   i·t_x(t)·(ρ_{j,j+1} − ρ_{j+1,j}) = i·t_eff·(conj(ρ_fwd) − ρ_fwd)
#                                       = 2·Re(t_eff)·Im(ρ_fwd)   (real)
# with t_eff(t) = t_x · exp(i·A_x(t)).

bonds_lc, bond_mpos_lc = TensorBinding.xbond_current_mpos(Lx_drv, N_drv, sites_drv)

nsteps_lc = length(states_drv)
nbonds_lc  = length(bonds_lc)
J_local    = Matrix{Float64}(undef, nsteps_lc, nbonds_lc)

for (step, ρ) in enumerate(states_drv)
    t     = (step - 1) * Float64(dt_drv)
    t_eff = t_x * exp(im * A_x(t))           # Peierls-dressed hopping
    for (b, mpo) in enumerate(bond_mpos_lc)
        ρ_fwd            = inner(mpo, ρ)      # ⟨c†_{j+1} c_j⟩ = ρ_{j+1,j}
        J_local[step, b] = real(im * t_eff * (conj(ρ_fwd) - ρ_fwd))
    end
end

bond_idx_lc = [j for (j, _) in bonds_lc]

heatmap(taxis, bond_idx_lc, J_local';
    xlabel         = "t",
    ylabel         = "bond j  (j → j+1)",
    title          = "Local x-current  i·tₓ(t)·(ρⱼ,ⱼ₊₁ − ρⱼ₊₁,ⱼ)",
    color          = :RdBu,
    colorbar_title = "Jⱼ(t)",
)
# Out:
# maxsamplevalue is zero!
#
# Stacktrace:
#   [1] error(s::String)
#     @ Base .\error.jl:35
#   [2] TensorCrossInterpolation.TensorCI2{ComplexF64}(func::TensorCrossInterpolation.CachedFunction{ComplexF64, UInt128}, localdims::Vector{Int64}, initialpivots::Vector{Vector{Int64}})
#     @ TensorCrossInterpolation C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\RnYi9\src\tensorci2.jl:51
#   [3] crossinterpolate2(::Type{ComplexF64}, f::Function, localdims::Vector{Int64}, initialpivots::Vector{Vector{Int64}}; kwargs::@Kwargs{nsearchglobalpivot::Int64, tolerance::Float64, strictlynested::Bool})
#     @ TensorCrossInterpolation C:\Users\tiagu\.julia\packages\TensorCrossInterpolation\RnYi9\src\tensorci2.jl:908
#   [4] quanticscrossinterpolate(::Type{ComplexF64}, f::Main.TensorBinding.var"#284#285"{Int64, Int64}, grid::QuanticsGrids.DiscretizedGrid{2}, initialpivots::Nothing; nrandominitpivot::Int64, kwargs::@Kwargs{tolerance::Float64})
#     @ QuanticsTCI C:\Users\tiagu\.julia\packages\QuanticsTCI\83MQR\src\tciinterface.jl:114
#   [5] hopping2MPO(f::Function, N::Int64, sites::Vector{Index{Int64}}; tol::Float64, initial_positions::Vector{Tuple{Int64, Int64}}, type::Type)
#     @ Main.TensorBinding c:\temp_docs\TensorBinding\TensorBinding.jl\src\Hamiltonian.jl:114
#   [6] hopping2MPO
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Hamiltonian.jl:100 [inlined]
#   [7] #single_bond_current_mpo#283
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:567 [inlined]
#   [8] single_bond_current_mpo
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:564 [inlined]
#   [9] #289
#     @ .\none:0 [inlined]
#  [10] iterate
#     @ .\generator.jl:48 [inlined]
#  [11] collect(itr::Base.Generator{Vector{Tuple{Int64, Int64}}, Main.TensorBinding.var"#289#292"{Float64, Int64, Vector{Index{Int64}}}})
#     @ Base .\array.jl:791
#  [12] #xbond_current_mpos#286
#     @ c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:587 [inlined]
#  [13] xbond_current_mpos(Lx::Int64, N::Int64, sites::Vector{Index{Int64}})
#     @ Main.TensorBinding c:\temp_docs\TensorBinding\TensorBinding.jl\src\Timeev_tk.jl:585
#  [14] top-level scope
#     @ In[10]:11
