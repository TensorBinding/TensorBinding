# %%
import Pkg; Pkg.resolve(); Pkg.instantiate()
# Out:
#      Project No packages added to or removed from `C:\Users\tripl\OneDrive\Bureau\PostdocProjects\TensorBinding\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\tripl\OneDrive\Bureau\PostdocProjects\TensorBinding\Manifest.toml`
# Precompiling packages...
#    2153.8 ms  ? TCIITensorConversion
#    4658.9 ms  ? TensorBinding

# %%
using LinearAlgebra
using Plots
using ITensors
using ITensorMPS
include("src/TensorBinding.jl")
using .TensorBinding
using QuanticsTCI
import TensorCrossInterpolation as TCI

# %%
L  = 5
H1 = TensorBinding.get_Hamiltonian("chain_1d", 1.0; L=L, scale=4.5)
# println(H1)
# Out:
# TBHamiltonian | L=5, N=32, scale=4.5, maxlinkdim=3 | geometry: 32 sites, 1D | no Tn cache
